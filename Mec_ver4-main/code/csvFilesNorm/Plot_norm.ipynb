# %%
from matplotlib import pyplot as plt

plt.rcParams["figure.figsize"] = [7.50, 3.50]
plt.rcParams["figure.autolayout"] = True

line1, = plt.plot([1, 2, 3], label="Line 1", linestyle='--')
line2, = plt.plot([3, 2, 1], label="Line 2", linewidth=4)

first_legend = plt.legend(handles=[line1], loc='upper right')

plt.gca().add_artist(first_legend)
plt.legend(handles=[line2], loc='lower right')

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('default')
import pandas as pd

plt.rcParams['figure.figsize'] = [12, 6]
plt.rcParams['figure.dpi'] = 100 # 200 e.g. is really fine, but slower
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
a = 0
b = 100
data4 = pd.read_csv("FDQO_5phut_M900_1000_0.85.csv").values[:101, 1]
data5 = pd.read_csv("FDQO_5phut_M900_1000_0.8_exlre0.0.csv").values[:101, 1]
data55 = pd.read_csv("FDQO_5phut_M900_1000_0.9_exlre0.0.csv").values[:101, 1]
data6 = pd.read_csv("FDQO_5phut_all_fuzzy.csv").values[:101, 1]
data7 = pd.read_csv("FDQO_5phut_M900_1000_0.2.csv").values[:101, 1]
data8 = pd.read_csv("FDQO_5phut_M900_1000_0.95_exlre0.0.csv").values[:101, 1]
#data9 = pd.read_csv("FDQO_5phut_M900_1000_1.0_exlre0.0.csv").values[:100, 1]
#data10 = pd.read_csv("FDQO_5phut_M900_1000_0.95_exlre0.0.csv").values[:100, 1]
data11 = pd.read_csv("FDQO_5phut_M900_1000_0.9_exlre0.1.csv").values[:101, 1]
data12 = pd.read_csv("FDQO_5phut_M900_1000_0.9_fuzzy0.95.csv").values[:101, 1]
print(data5.shape)
dataFDQO_all_fuzzy = pd.read_csv("FDQO_5phut_all_fuzzy.csv").values[:, 1]
number = [i for i in range(data4.shape[0])]
line1, = ax.plot(number, data5, color="red", label = "FDQO $\Theta = 0.8$")
line2, = ax.plot(number, [np.average(data5[a:b])] * data4.shape[0], color="red", linestyle = '--',
        label = "mean FDQO $\Theta = 0.8$")
line3, = ax.plot(number, data4, color="blue", label = "FDQO $\Theta = 0.85$")
line4, = ax.plot(number, [np.average(data4[a:b])] * data4.shape[0], color="blue", linestyle = '--',
        label = "mean FDQO $\Theta = 0.85$")
line5, = ax.plot(number, data55, color="green", label = "FDQO $\Theta = 0.9$")
line6, = ax.plot(number, [np.average(data55[a:b])] * data55.shape[0], color="green", linestyle = '--',
        label = "mean FDQO $\Theta = 0.9$")
line7, = ax.plot(number, data8, color="purple", label = "FDQO $\Theta = 0.95$")
line8, = ax.plot(number, [np.average(data8[a:b])] * data6.shape[0], color="purple", linestyle = '--',
        label = "mean FDQO $\Theta = 0.95$")
line9, = ax.plot(number, data6, color="orange", label = "FDQO $\Theta = 1.0$")
line10, = ax.plot(number, [np.average(data6[a:b])] * data6.shape[0], color="orange", linestyle = '--',
        label = "mean FDQO $\Theta = 1.0$")
# plt.plot(number, data7, color="purple", label = "FDQO")
# plt.plot(number, [np.average(data7[a:b])] * data6.shape[0], color="purple", linestyle = '--')
# plt.plot(number, data9, color="black", label = "FDQO 1.0 exlre 0.0")
# plt.plot(number, [np.average(data9[a:b])] * data6.shape[0], color="black", linestyle = '--')
# plt.plot(number, data10, color="gray", label = "FDQO 0.95 exlre 0.0")
# plt.plot(number, [np.average(data10[a:b])] * data6.shape[0], color="gray")
# plt.plot(number, data11, color="red", label = "FDQO 0.9 exlre 0.1")
# plt.plot(number, [np.average(data11[a:b])] * data11.shape[0], color="red", linestyle = '--')
# plt.plot(number, data12, color="orange", label = "FDQO 0.9 fuzzy 0.95")
# plt.plot(number, [np.average(data12[a:b])] * data12.shape[0], color="orange", linestyle = '--')
#plt.title("Different thresholds of FDQOs")
ax.set_xlabel("Time slots")
ax.set_ylabel("Average QoE")
first_legend = plt.legend(handles=[line2, line4, line6, line8, line10], loc='lower right')
plt.gca().add_artist(first_legend)
plt.legend(handles=[line1, line3, line5, line7, line9], loc='upper center',
           ncol=5, fancybox=True, shadow=True)

# plt.legend(loc='upper center',
#           ncol=5, fancybox=True, shadow=True)
#ax.set_xticks(np.arange(0, 101, 5.0))
ax.axis([0, 100, 0, 1])
major_ticks = np.arange(0, 101, 20)
minor_ticks = np.arange(0, 101, 5)

ax.set_xticks(major_ticks)
ax.set_xticks(minor_ticks, minor=True)
ax.set_yticks(np.arange(0,1.05,0.2))
ax.set_yticks(np.arange(0,1.05,0.05), minor=True)

ax.grid(which='both')

# Or if you want different settings for the grids:
ax.grid(which='minor', alpha=0.2)
ax.grid(which='major', alpha=0.5)
plt.savefig("../../Pictures/Diffent_thresholds_FDQO.pdf")
plt.show()
# Out:
# (101,)

# %%
# !pip install latex
# Out:
# ...
#   Created wheel for latex: filename=latex-0.7.0-py3-none-any.whl size=7605 sha256=4bfb4264f13188861c2c93dcb64f6f417eef0680502fdcecb7eaf0eada6a2db2
#   Stored in directory: c:\users\mrhiep\appdata\local\pip\cache\wheels\16\c1\33\30e79ef1232ec43bb51b17ad60c5bfa6849fa0c9bc939ca089
# ...
#   Created wheel for data: filename=data-0.4-py3-none-any.whl size=7246 sha256=c9b4c800a9bbf96004bd4c1c4a09a03d3f1d3b991a42a865926e791f3614f287
#   Stored in directory: c:\users\mrhiep\appdata\local\pip\cache\wheels\5c\78\30\ac68ac8de8481b3b4334617a48ef1758323f30709b2f923362
# ...
#   Created wheel for shutilwhich: filename=shutilwhich-1.1.0-py3-none-any.whl size=2782 sha256=a0681aa64a38ae710dbdd19c119f60c851856a9bf96d05465431027beaa3b663
#   Stored in directory: c:\users\mrhiep\appdata\local\pip\cache\wheels\27\f1\8b\8e9215b5809387fcf93d0eb9c1a95a7cb30b369b3c1d986f1c
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('ggplot')
import pandas as pd

plt.rcParams['figure.figsize'] = [12, 6]
plt.rcParams['figure.dpi'] = 100 # 200 e.g. is really fine, but slower

a = 0
b = 100
data1 = pd.read_csv("DQL_5phut_M900_1000_mem25_2.csv").values[:100, 1]
data2 = pd.read_csv("BDQL_5phut_M900_1000_0.1_0.05_b0.6_fix_3.csv").values[:100, 1]
data5 = pd.read_csv("DDQL_5phut_M900_1000_1.csv").values[:100, 1]
data55 = pd.read_csv("DDQL_5phut_M900_1000_1_under.csv").values[:100, 1]
data6 = pd.read_csv("BDQL_5phut_M900_1000_0.1_0.05_b0.6_que5000_fix.csv").values[:100, 1]
data7 = pd.read_csv("BDQL_5phut_M900_1000_dyn_e0.1_k0.3_que10k_b0.5.csv").values[:100, 1]
data8 = pd.read_csv("RGreedy_5phut.csv").values[:100, 2]
data9 = pd.read_csv("DQL_5phut_new_0.2.csv").values[:, 1]
data10 = pd.read_csv("DQL_5phut_second_base_0.2.csv").values[:, 1]
print(data9.shape)
dataFDQO_all_fuzzy = pd.read_csv("FDQO_5phut_all_fuzzy.csv").values[:, 1]
number = [i + 1 for i in range(data2.shape[0])]
plt.plot(number, data1, color="red", label = "DQL")
Waverage1 = np.average(data1[0:100])
Laverage1 = np.average(data1[50:100])
plt.plot(number, [np.average(data1[a:b])] * data2.shape[0], color="red", linestyle = '--')
# plt.plot(number, data2, color="red", label = "Static BDQL 0.1_0.05_b0.6")
# Waverage2 = np.average(data2[0:100])
# Laverage2 = np.average(data2[50:100])
# plt.plot(number, [np.average(data2[a:b])] * data2.shape[0], color="red", linestyle = '--')
plt.plot(number, data5, color="blue", label = "DDQL")
Waverage5 = np.average(data5[0:100])
Laverage5 = np.average(data5[50:100])
plt.plot(number, [np.average(data5[a:b])] * data2.shape[0], color="blue", linestyle = '--')
# plt.plot(number, data55, color="blue", label = "DDQL under", linestyle = '-.')
# plt.plot(number, [np.average(data55[a:b])] * data55.shape[0], color="blue", linestyle = ':')
plt.plot(number, data6, color="green", label = "baseline DQL 0.1_0.05_b0.6 queue 5000")
Waverage6 = np.average(data6[0:100])
Laverage6 = np.average(data6[50:100])
plt.plot(number, [np.average(data6[a:b])] * data6.shape[0], color="green", linestyle = '--')
plt.plot(number, data7, color="purple", label = "Dyn DQL e0.1 k0.3 b0.5")
Waverage7 = np.average(data7[0:100])
Laverage7 = np.average(data7[50:100])
plt.plot(number, [np.average(data6[a:b])] * data6.shape[0], color="purple", linestyle = '--')
#plt.plot(number, data8, color="gray", label = "RGreedy")
# plt.plot(number, [np.average(data8[a:b])] * data8.shape[0], color="gray", linestyle = '--')
#plt.plot(number, [np.average(data7[a:b])] * data6.shape[0], color="purple", linestyle = '--')
# plt.plot(number, data9, color="purple", label = "DQL base 0.2")
# plt.plot(number, [np.average(data9[a:b])] * data6.shape[0], color="purple", linestyle = '--')
# plt.plot(number, data10, color="gray", label = "DQL base 0.2 with 0.05 exp")
# plt.plot(number, [np.average(data10[a:b])] * data6.shape[0], color="gray", linestyle = '--')
plt.title("900 - 1000 tasks per episode, average: " + str(a) + " - " + str(b))
plt.legend(loc='upper center', bbox_to_anchor=(0.32, 0.99),
          ncol=2, fancybox=True, shadow=True)
plt.xticks(np.arange(0, 101, 5.0))
plt.axis([0, 100, 0, 1])
plt.show()

plt.clf()
df = pd.DataFrame({
    'Name': ['DQL', 'BDQL', 'DDQL', 'q-BDQL',
            'dyn BDQL'],
    'Average QoE of all episodes': [Waverage1, Waverage2, Waverage5, Waverage6, Waverage7],
    'Average QoE of the last 50 episodes': [Laverage1, Laverage2, Laverage5, Laverage6, Laverage7]
})
  
# plotting graph
df.plot(x="Name", y=["Average QoE of all episodes", 
                     "Average QoE of the last 50 episodes"], kind="bar", ylim = [0, 0.8])
plt.plot([-1,1,2,3,5], [max(df['Average QoE of all episodes'])] * 5, color="red", linestyle = '--')
plt.plot([-1,1,2,3,5], [max(df['Average QoE of the last 50 episodes'])] * 5, color="royalblue", linestyle = '--')
# Out:
# (109,)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-6c46809264b7> in <module>
#      61     'Name': ['DQL', 'BDQL', 'DDQL', 'q-BDQL',
#      62             'dyn BDQL'],
# ---> 63     'Average QoE of all episodes': [Waverage1, Waverage2, Waverage5, Waverage6, Waverage7],
#      64     'Average QoE of the last 50 episodes': [Laverage1, Laverage2, Laverage5, Laverage6, Laverage7]
#      65 })
#
# NameError: name 'Waverage2' is not defined

# %%
df = pd.DataFrame({
    'Name': ['DQL', 'FDQO', 'DDQL', 'BDQL',
            'dyn BDQL'],
    'Average QoE of the first 50 episodes': [Baverage1, Baverage55, Baverage5, Baverage6, Baverage7],
    'Average QoE of all episodes': [Waverage1, Waverage55, Waverage5, Waverage6, Waverage7],
    'Average QoE of the last 50 episodes': [Laverage1, Laverage55, Laverage5, Laverage6, Laverage7]
})
colors = ['#BB0000', '#0000BB', 'green']

# plotting graph
df.plot.bar(x="Name", y=["Average QoE of the first 50 episodes", "Average QoE of all episodes", 
                     "Average QoE of the last 50 episodes"], color={"Average QoE of the first 50 episodes": "red",
                     "Average QoE of all episodes": "green", "Average QoE of the last 50 episodes": "blue"},
                     ylim = [0, 0.8])
plt.plot([-1,1,2,3,5], [max(df['Average QoE of the first 50 episodes'])] * 5, color="red", linestyle = '--')
plt.plot([-1,1,2,3,5], [max(df['Average QoE of all episodes'])] * 5, color="green", linestyle = '--')
plt.plot([-1,1,2,3,5], [max(df['Average QoE of the last 50 episodes'])] * 5, color="blue", linestyle = '--')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-4661dacf18c7> in <module>
#       2     'Name': ['DQL', 'FDQO', 'DDQL', 'BDQL',
#       3             'dyn BDQL'],
# ----> 4     'Average QoE of the first 50 episodes': [Baverage1, Baverage55, Baverage5, Baverage6, Baverage7],
#       5     'Average QoE of all episodes': [Waverage1, Waverage55, Waverage5, Waverage6, Waverage7],
#       6     'Average QoE of the last 50 episodes': [Laverage1, Laverage55, Laverage5, Laverage6, Laverage7]
#
# NameError: name 'Baverage55' is not defined

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('default')
import pandas as pd

plt.rcParams['figure.figsize'] = [12, 6]
plt.rcParams['figure.dpi'] = 100 # 200 e.g. is really fine, but slower
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

a = 5
b = 70
#data1 = pd.read_csv("RGreedy_5phut.csv").values[:100, 2]
data2 = pd.read_csv("DQL_5phut_M900_1000_mem25_4.csv").values[:101, 1]
data5 = pd.read_csv("DDQL_5phut_M900_1000_mem25_3.csv").values[:101, 1]
data6 = pd.read_csv("BDQL_5phut_M900_1000_0.1_0.05_b0.6_que5000_fix.csv").values[:101, 1]
#data6 = pd.read_csv("BDQL_5phut_M900_1000_0.1_0.05_b0.6_fix_.csv").values[:101, 1]
data7 = pd.read_csv("BDQL_5phut_M900_1000_dyn_e0.1_k0.3_que10k_b0.5.csv").values[:101, 1]
#data8 = pd.read_csv("Sarsa_5phut_M900_1000.csv").values[:101, 1]
number = [i for i in range(data2.shape[0])]
# plt.plot(number, data1, color="gray", label = "Greedy")
# Baverage1 = np.average(data1[0:a])
# Waverage1 = np.average(data1[0:100])
# Laverage1 = np.average(data1[b:100])
#plt.plot(number, [np.average(data1[a:b])] * data2.shape[0], color="red", linestyle = '--')
ax.plot(number, data2, color="red", label = "DQN")
Baverage2 = np.average(data2[0:a])
Waverage2 = np.average(data2[0:100])
Laverage2 = np.average(data2[b:100])
#plt.plot(number, [np.average(data2[a:b])] * data2.shape[0], color="red", linestyle = '--')
ax.plot(number, data5, color="blue", label = "DDQN")
Baverage5 = np.average(data5[0:a])
Waverage5 = np.average(data5[0:100])
Laverage5 = np.average(data5[b:100])
#plt.plot(number, [np.average(data5[a:b])] * data2.shape[0], color="blue", linestyle = '--')
# plt.plot(number, data55, color="blue", label = "DDQL under", linestyle = '-.')
# plt.plot(number, [np.average(data55[a:b])] * data55.shape[0], color="blue", linestyle = ':')
ax.plot(number, data6, color="orange", label = "Sb-DQN")
Baverage6 = np.average(data6[0:a])
Waverage6 = np.average(data6[0:100])
Laverage6 = np.average(data6[b:100])
#plt.plot(number, [np.average(data6[a:b])] * data6.shape[0], color="green", linestyle = '--')
ax.plot(number, data7, color="green", label = "Db-DQN")
Baverage7 = np.average(data7[0:a])
Waverage7 = np.average(data7[0:100])
Laverage7 = np.average(data7[b:100])

# ax.plot(number, data8, color="pink", label = "Sarsa")
# Baverage8 = np.average(data8[0:a])
# Waverage8 = np.average(data8[0:100])
# Laverage8 = np.average(data8[b:100])
# plt.plot(number, data9, color="purple", label = "DQL base 0.2")
# plt.plot(number, [np.average(data9[a:b])] * data6.shape[0], color="purple", linestyle = '--')
# plt.plot(number, data10, color="gray", label = "DQL base 0.2 with 0.05 exp")
# plt.plot(number, [np.average(data10[a:b])] * data6.shape[0], color="gray", linestyle = '--')
#plt.title("900 - 1000 tasks per episode, average: " + str(a) + " - " + str(b))
plt.xlabel("Time slots")
plt.ylabel("Average QoE")
plt.legend(ncol=2, fancybox=True, shadow=True)
# plt.xticks(np.arange(0, 101, 5.0))
# plt.axis([0, 100, 0, 1])
# plt.grid()
ax.axis([0, 100, 0, 1])
major_ticks = np.arange(0, 101, 20)
minor_ticks = np.arange(0, 101, 5)

ax.set_xticks(major_ticks)
ax.set_xticks(minor_ticks, minor=True)
ax.set_yticks(np.arange(0,1.05,0.2))
ax.set_yticks(np.arange(0,1.05,0.05), minor=True)

ax.grid(which='both')

# Or if you want different settings for the grids:
ax.grid(which='minor', alpha=0.2)
ax.grid(which='major', alpha=0.5)
#plt.savefig("../../Pictures/No_Fuzzy_Algos.pdf")
plt.show()

plt.clf()
df = pd.DataFrame({
    '': ['DQN', 'DDQN', 'Sb-DQN', 'Db-DQN'],
    'Average QoE of the first '+str(a)+' time slots': [Baverage2, Baverage5, Baverage6, Baverage7],
    'Average QoE of all time slots': [Waverage2, Waverage5, Waverage6, Waverage7],
    'Average QoE of the last '+str(100-b)+' time slots': [Laverage2, Laverage5, Laverage6, Laverage7]
})

# plotting graph
df.plot.bar(x="", y=["Average QoE of the first "+str(a)+" time slots", "Average QoE of all time slots", 
                     "Average QoE of the last "+str(100-b)+" time slots"], color={"Average QoE of the first "+str(a)+" time slots": "red",
                     "Average QoE of all time slots": "green", "Average QoE of the last "+str(100-b)+" time slots": "blue"},
                     ylim = [0, 1], rot = 0)
plt.ylabel("Average QoE")
plt.grid()
plt.plot([-1,1,2,4], [max(df['Average QoE of the first '+str(a)+' time slots'])] * 4, color="red", linestyle = '--')
plt.plot([-1,1,2,4], [max(df['Average QoE of all time slots'])] * 4, color="green", linestyle = '--')
plt.plot([-1,1,2,4], [max(df['Average QoE of the last '+str(100-b)+' time slots'])] * 4, color="blue", linestyle = '--')
plt.savefig("../../Pictures/No_Fuzzy_Algos_Statistic_2.pdf")

# %%
def statistic(temp):
    print(round(temp.mean(),2), round(temp[0:a].mean(),2), round(temp[b:100].mean(),2),
          round(temp.std(),2), round(temp.min(),2), round(temp.max(),2))
statistic(data1)
statistic(data2)
statistic(data5)
statistic(data6)
statistic(data7)
# Out:
# 0.52 0.54 0.51 0.05 0.42 0.69
# 0.6 0.26 0.63 0.1 0.09 0.79
# 0.49 0.12 0.62 0.18 0.04 0.75
# 0.62 0.23 0.66 0.12 0.14 0.82
# 0.64 0.35 0.67 0.1 0.06 0.79

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('default')
import pandas as pd

plt.rcParams['figure.figsize'] = [12, 6]
plt.rcParams['figure.dpi'] = 100 # 200 e.g. is really fine, but slower
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

a = 5
b = 70
data1 = pd.read_csv("FDQO_5phut_M900_1000_baseline_0.5_dyn_e0.1_k0.3_que3k_b0.5_c0.9.csv").values[:101, 1]
data5 = pd.read_csv("FDQO_5phut_M900_1000_0.9_exlre0.0.csv").values[:101, 1]
data7 = pd.read_csv("BDQL_5phut_M900_1000_dyn_e0.1_k0.3_que10k_b0.5.csv").values[:101, 1]
data8 = pd.read_csv("RGreedy_5phut.csv").values[:101, 2]
number = [i for i in range(data1.shape[0])]
ax.plot(number, data1, color="green", label = "b-FDQO")
Baverage1 = np.average(data1[0:a])
Waverage1 = np.average(data1[0:100])
Laverage1 = np.average(data1[b:100])

#plt.plot(number, [np.average(data2[a:b])] * data2.shape[0], color="red", linestyle = '--')
ax.plot(number, data5, color="blue", label = "FDQO")
Baverage5 = np.average(data5[0:a])
Waverage5 = np.average(data5[0:100])
Laverage5 = np.average(data5[b:100])

#plt.plot(number, [np.average(data6[a:b])] * data6.shape[0], color="green", linestyle = '--')
ax.plot(number, data7, color="red", label = "Db-DQN")
Baverage7 = np.average(data7[0:a])
Waverage7 = np.average(data7[0:100])
Laverage7 = np.average(data7[b:100])
# plt.plot(number, [np.average(data6[a:b])] * data6.shape[0], color="purple", linestyle = '--')
ax.plot(number, data8, color="gray", label = "Greedy")
Baverage8 = np.average(data8[0:a])
Waverage8 = np.average(data8[0:100])
Laverage8 = np.average(data8[b:100])
#plt.plot(number, [np.average(data7[a:b])] * data6.shape[0], color="purple", linestyle = '--')
# plt.plot(number, data9, color="purple", label = "DQL base 0.2")
# plt.plot(number, [np.average(data9[a:b])] * data6.shape[0], color="purple", linestyle = '--')
# plt.plot(number, data10, color="gray", label = "DQL base 0.2 with 0.05 exp")
# plt.plot(number, [np.average(data10[a:b])] * data6.shape[0], color="gray", linestyle = '--')
#plt.title("900 - 1000 tasks per episode, average: " + str(a) + " - " + str(b))
plt.xlabel("Time slots")
plt.ylabel("Average QoE")
plt.legend(fancybox=True, shadow=True)
# plt.xticks(np.arange(0, 101, 5.0))
# plt.axis([0, 100, 0, 1])
ax.axis([0, 100, 0, 1])
major_ticks = np.arange(0, 101, 20)
minor_ticks = np.arange(0, 101, 5)

ax.set_xticks(major_ticks)
ax.set_xticks(minor_ticks, minor=True)
ax.set_yticks(np.arange(0,1.05,0.2))
ax.set_yticks(np.arange(0,1.05,0.05), minor=True)

ax.grid(which='both')

# Or if you want different settings for the grids:
ax.grid(which='minor', alpha=0.2)
ax.grid(which='major', alpha=0.5)
plt.savefig("../../Pictures/bFDQO_vs_others.pdf")
plt.show()

plt.clf()
# df = pd.DataFrame({
#     'Name': ['b-FDQO', 'Greedy', 'FDQO'],
#     'Average QoE of the first '+str(a)+' episodes': [Baverage1, Baverage5, Baverage7],
#     'Average QoE of all episodes': [Waverage1, Waverage5, Waverage7],
#     'Average QoE of the last '+str(100-b)+' episodes': [Laverage1, Laverage5, Laverage7]
# })

# # plotting graph
# df.plot.barh(x="Name", y=["Average QoE of the first "+str(a)+" episodes", "Average QoE of all episodes", 
#                      "Average QoE of the last "+str(100-b)+" episodes"], color={"Average QoE of the first "+str(a)+" episodes": "red",
#                      "Average QoE of all episodes": "green", "Average QoE of the last "+str(100-b)+" episodes": "blue"},
#                      lim = [0, 0.8])

#plt.plot([-1,1,3], [max(df['Average QoE of the first '+str(a)+' episodes'])] * 3, color="red", linestyle = '--')
#plt.plot([-1,1,3], [max(df['Average QoE of all episodes'])] * 3, color="green", linestyle = '--')
#plt.plot([-1,1,3], [max(df['Average QoE of the last '+str(100-b)+' episodes'])] * 3, color="blue", linestyle = '--')



# fig, ax = plt.subplots()
# label1 = "Average QoE of the first "+str(a)+" time slots"
# label2 = "Average QoE of all time slots"
# label3 = "Average QoE of the last "+str(100-b)+" time slots"

# a = {'Greedy': {label3: Laverage8, label2: Waverage8, label1: Baverage8},
#     'Db-DQN': {label3: Laverage7, label2: Waverage7, label1: Baverage7},
#     'FDQO': {label3: Laverage5, label2: Waverage5, label1: Baverage5},    
#     'b-FDQO': {label3: Laverage1, label2: Waverage1, label1: Baverage1}}
# label1_value = [a['b-FDQO'][label1], a['FDQO'][label1], a['Db-DQN'][label1]]
# label2_value = [a['b-FDQO'][label2], a['FDQO'][label2], a['Db-DQN'][label2]]
# label3_value = [a['b-FDQO'][label3], a['FDQO'][label3], a['Db-DQN'][label3]]
# d = pd.DataFrame(a).T

# f = plt.figure()

# d.plot(kind='barh', color={label3: "darkorchid",
#                      label2: "gold", label1: "salmon"}, legend = 'reverse', ax = ax)
# handles, labels = ax.get_legend_handles_labels()
# ax.legend(handles[::-1], labels[::-1], loc='center left', bbox_to_anchor=(0, 1.1), ncol = 3)
# #plt.legend(loc='center left', bbox_to_anchor=(0, 1.1), ncol = 3)
# ax.axvline(min(label3_value), color = 'darkorchid', linestyle = ':' )
# #ax.axvline(min(label2_value), color = 'gold', linestyle = ':')
# ax.axvline(min(label1_value), color = 'salmon', linestyle = ':')
# ax.set_xlabel("Average QoE")
# ax.figure.savefig("../../Pictures/bFDQO_vs_others_statistic.pdf")

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('default')
import pandas as pd

plt.rcParams['figure.figsize'] = [12, 6]
plt.rcParams['figure.dpi'] = 100 # 200 e.g. is really fine, but slower
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

data1 = pd.read_csv("FDQO_5phut_M900_1000_baseline_0.5_dyn_e0.1_k0.3_que3k_b0.5_c0.9.csv").values[:101, 1]
data5 = pd.read_csv("FDQO_5phut_M900_1000_0.9_exlre0.0.csv").values[:101, 1]
data7 = pd.read_csv("BDQL_5phut_M900_1000_dyn_e0.1_k0.3_que10k_b0.5.csv").values[:101, 1]
data8 = pd.read_csv("RGreedy_5phut.csv").values[:101, 2]
number = [i for i in range(data1.shape[0])]
df1 = pd.DataFrame(data=data1, columns=["value"])
df5 = pd.DataFrame(data=data5, columns=["value"])
df7 = pd.DataFrame(data=data7, columns=["value"])
df8 = pd.DataFrame(data=data8, columns=["value"])
moving_average_step = 40
df_ma1 = df1.value.rolling(moving_average_step, center=False, closed='left').mean()
df_ma5 = df5.value.rolling(moving_average_step, center=False, closed='left').mean()
df_ma7 = df7.value.rolling(moving_average_step, center=False, closed='left').mean()
df_ma8 = df8.value.rolling(moving_average_step, center=False, closed='left').mean()
df_ma1.plot(color="green", label = "b-FDQO")
df_ma5.plot(color="blue", label = "FDQO")
df_ma7.plot(color="red", label = "Db-DQN")
df_ma8.plot(color="gray", label = "Greedy")
plt.xlabel("Time slots")
plt.ylabel("Average QoE")
plt.legend(fancybox=True, shadow=True)
# plt.xticks(np.arange(0, 101, 5.0))
# plt.axis([0, 100, 0, 1])
ax.axis([moving_average_step, 100, 0.5, 0.7])
major_ticks = np.arange(moving_average_step, 101, 20)
minor_ticks = np.arange(moving_average_step, 101, 5)

ax.set_xticks(major_ticks)
ax.set_xticks(minor_ticks, minor=True)
ax.set_yticks(np.arange(0.5,0.75,0.2))
ax.set_yticks(np.arange(0.5,0.75,0.05), minor=True)

ax.grid(which='both')

# Or if you want different settings for the grids:
ax.grid(which='minor', alpha=0.2)
ax.grid(which='major', alpha=0.5)
#plt.savefig("../../Pictures/bFDQO_vs_others_moving_average.pdf")
plt.show()

# %%
color="blue", label = "FDQO"
color="red", label = "Db-DQL"
color="gray", label = "Greedy"
# Out:
# (30.0, 100.0, 0.0, 1.0)

# %%
print(a['b-FDQO'][label1])
b = [a['b-FDQO'][label1], a['FDQO'][label1], a['Db-DQN'][label1]]
b
# Out:
# 0.6582979721489995
# [0.6582979721489995, 0.6368520389602346, 0.6732755346488566]

# %%
data55 = pd.read_csv("FDQO_5phut_M900_1000_0.9_exlre0.0.csv").values[:100, 1]
Waverage55 = np.average(data55[0:100])
Laverage55 = np.average(data55[50:100])
Baverage55 = np.average(data55[0:50])
Baverage1 = np.average(data1[0:50])
Baverage5 = np.average(data5[0:50])
Baverage6 = np.average(data6[0:50])
Baverage7 = np.average(data7[0:50])

# %%
# importing pandas library
import pandas as pd
# import matplotlib library
import matplotlib.pyplot as plt
  
# creating dataframe
df = pd.DataFrame({
    'Name': ['DQL', 'BDQL', 'DDQL', 'QDQL',
            'dyn DQL'],
    'Average QoE of all episodes': [Waverage1, Waverage2, Waverage5, Waverage6, Waverage7],
    'Average QoE of the last 50 episodes': [Laverage1, Laverage2, Laverage5, Laverage6, Laverage7]
})
  
# plotting graph
df.plot(x="Name", y=["Average QoE of all episodes", 
                     "Average QoE of the last 50 episodes"], kind="bar", ylim = [0, 0.8])
plt.plot([-1,1,2,3,5], [Waverage6] * 5, color="red", linestyle = '--')
plt.plot([-1,1,2,3,5], [Laverage6] * 5, color="royalblue", linestyle = '--')

# %%
pwd
# Out:
# 'D:\\Binh\\Projects\\New\\Luutam\\Mec_ver4-main\\code\\csvFilesNorm'

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('default')
import pandas as pd

plt.rcParams['figure.figsize'] = [12, 4]
plt.rcParams['figure.dpi'] = 100 # 200 e.g. is really fine, but slower

plt.clf()
df = pd.read_csv("kqDQN_M900_1000_mem25_4.csv").values
#df = pd.read_csv("kqDDQN_M900_1000_mem25_3.csv").values
df = df[:int(df.shape[0]+1),0]
#df_slide_1000 = [df[i:(i+1000)] for i in 299]
df = df.flatten()
df_list = df.tolist()
df_list
data = pd.read_csv("DQL_5phut_M900_1000_mem25_4.csv").values
#data = pd.read_csv("DDQL_5phut_M900_1000_mem25_3.csv").values
nb_steps = data[:,5].flatten().tolist()
step = data[:,6].flatten().tolist()
# df_list_splice = [list(df_list[int(i - j): int(i)]) for j in nb_steps for i in step]
# df_list_splice
test = [df_list[int(i - j): int(i)] for j, i in zip(nb_steps, step)]
test.pop(-1) # somehow the last is empty
sum_of_subtest = [sum(sublist) / len(sublist) * 100 for sublist in test]
plt.fill_between([i for i in range(len(sum_of_subtest))], 0, sum_of_subtest)
#plt.title("Percentage of exploration (DDQN)")
plt.xlabel("Time slots")
plt.ylabel("%")
plt.axis([0, 100, 0, 20])
#plt.savefig("../../Pictures/Percentage_DQN.pdf")
#plt.savefig("../../Pictures/Percentage_DDQN.pdf")
xmin, xmax = 0, 100 
min_hline, average_hline, max_hline = confidence_interval(sum_of_subtest[0:101])
err = average_hline - min_hline
plt.axhline(min_hline, color = 'red', linestyle = ':' )
plt.axhline(max_hline, color = 'red', linestyle = ':' )
plt.axhline(average_hline, color = 'red', linestyle = '-' )
plt.text(xmax + 1, average_hline - 8, '$ '+str(round(average_hline,2))+'\pm '+
         str(round(err,2))+'$ (95% CI)', fontsize = 15, color = 'red', rotation=-90)
plt.gca().xaxis.label.set_size(15)
plt.gca().yaxis.label.set_size(15)
plt.tick_params(which='major', labelsize=15)
plt.savefig("../../Pictures/Percentage_DQN_2.pdf", bbox_inches='tight')
#plt.savefig("../../Pictures/Percentage_DDQN_2.pdf", bbox_inches='tight')

# %%
import numpy as np, scipy.stats as st
import scipy
import math
import matplotlib.pyplot as plt
plt.style.use('default')
import pandas as pd

plt.rcParams['figure.figsize'] = [12, 4]
plt.rcParams['figure.dpi'] = 100 # 200 e.g. is really fine, but slower
def confidence_interval(a):
    n = len(a)
    if n < 30:
        min, max = st.t.interval(0.95, len(a)-1, loc=np.mean(a), scale=st.sem(a))
        #st.t.interval(0.95, 5, 101.82, 1.2/math.sqrt(6))
        return min, (min + max) / 2, max
    a = 1.0 * np.array(a)
    m, se = np.mean(a), scipy.stats.sem(a)
    h = 1.96 * a.std() / math.sqrt(n)
    return m-h, m, m+h
confidence_interval(sum_of_subtest[0:10])
# Out:
# (9.1368443190996, 9.642834245346235, 10.148824171592869)

# %%
scipy.stats.norm

# %%
import numpy as np
import scipy.stats
import math

def mean_confidence_interval(data, confidence=0.95):
    a = 1.0 * np.array(data)
    n = len(a)
    m, se = np.mean(a), scipy.stats.sem(a)
    h = se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)
    return m, m-h, m+h
print(mean_confidence_interval(sum_of_subtest[0:101], 0))
min(sum_of_subtest[0:101])
# Out:
# (9.88768853065427, 9.88768853065427, 9.88768853065427)
# 8.036622583926754

# %%
1.0 * np.array(sum_of_subtest[0:101]).std()
# Out:
# 0.958107546098598

# %%
plt.clf()
df = pd.read_csv("kqBDQN_M900_1000_0.1_0.05_b0.6_que5000_fix.csv").values
df = df[:int(df.shape[0]+1),0]
#df_slide_1000 = [df[i:(i+1000)] for i in 299]
df = df.flatten()
df_list = df.tolist()
df_list
data = pd.read_csv("BDQL_5phut_M900_1000_0.1_0.05_b0.6_que5000_fix.csv").values
nb_steps = data[:,5].flatten().tolist()
step = data[:,6].flatten().tolist()
# df_list_splice = [list(df_list[int(i - j): int(i)]) for j in nb_steps for i in step]
# df_list_splice
test = [df_list[int(i - j): int(i)] for j, i in zip(nb_steps, step)]
test.pop(-1) # somehow the last is empty
sum_of_subtest = [sum(sublist) / len(sublist) * 100 for sublist in test]
plt.fill_between([i for i in range(len(sum_of_subtest))], 0, sum_of_subtest)
#plt.title("Percentage of exploration (Sb-DQN)")
plt.xlabel("Time slots")
plt.ylabel("%")
plt.axis([0, 100, 0, 20])
xmin, xmax = 40, 101 
min_hline, average_hline, max_hline = confidence_interval(sum_of_subtest[xmin:xmax])
err = average_hline - min_hline
plt.hlines(y=min_hline, xmin=xmin, xmax=xmax, linewidth=2, color='r', linestyle = ':')
plt.hlines(y=max_hline, xmin=xmin, xmax=xmax, linewidth=2, color='r', linestyle = ':')
plt.hlines(y=average_hline, xmin=xmin, xmax=xmax, linewidth=2, color='r', linestyle = '-')
plt.vlines(x = xmin, ymin = 0, ymax=20, linewidth=2, color='r', linestyle = ':')
plt.text(xmax, average_hline - 5, '$ '+str(round(average_hline,2))+'\pm '+
         str(round(err,2))+'$ (95% CI)', fontsize = 15, color = 'red', rotation=-90)#, weight='bold')

xmin, xmax = 0, 20 
min_hline, average_hline, max_hline = confidence_interval(sum_of_subtest[xmin:xmax])
err = average_hline - min_hline
err = average_hline - min_hline
plt.hlines(y=min_hline, xmin=xmin, xmax=xmax, linewidth=2, color='r', linestyle = ':')
plt.hlines(y=max_hline, xmin=xmin, xmax=xmax, linewidth=2, color='r', linestyle = ':')
plt.hlines(y=average_hline, xmin=xmin, xmax=xmax, linewidth=2, color='r', linestyle = '-')
plt.vlines(x = xmax, ymin = 0, ymax=20, linewidth=2, color='r', linestyle = ':')
plt.text(xmax+1, average_hline - 6, '$ '+str(round(average_hline,2))+'\pm '+
         str(round(err,2))+'$ (95% CI)', fontsize = 15, color = 'red', rotation=-90)#, weight='bold')
plt.gca().xaxis.label.set_size(15)
plt.gca().yaxis.label.set_size(15)
plt.tick_params(which='major', labelsize=15)
plt.savefig("../../Pictures/Percentage_SbDQN_2.pdf", bbox_inches='tight')
plt.show()

# %%
plt.clf()
df = pd.read_csv("kqBDQN_M900_1000_dyn_e0.1_k0.3_que10k_b0.5.csv").values
df = df[:int(df.shape[0]+1),0]
#df_slide_1000 = [df[i:(i+1000)] for i in 299]
df = df.flatten()
df_list = df.tolist()
df_list
data = pd.read_csv("BDQL_5phut_M900_1000_dyn_e0.1_k0.3_que10k_b0.5.csv").values
nb_steps = data[:,5].flatten().tolist()
step = data[:,6].flatten().tolist()
# df_list_splice = [list(df_list[int(i - j): int(i)]) for j in nb_steps for i in step]
# df_list_splice
test = [df_list[int(i - j): int(i)] for j, i in zip(nb_steps, step)]
test.pop(-1) # somehow the last is empty
sum_of_subtest = [sum(sublist) / len(sublist) * 100 for sublist in test]
plt.fill_between([i for i in range(len(sum_of_subtest))], 0, sum_of_subtest)
#plt.title("Percentage of exploration (Db-DQN)")
plt.xlabel("Time slots")
plt.ylabel("%")
plt.axis([0, 100, 0, 20])
xmin, xmax = 40, 101 
min_hline, average_hline, max_hline = confidence_interval(sum_of_subtest[xmin:xmax])
err = average_hline - min_hline
plt.hlines(y=min_hline, xmin=xmin, xmax=xmax, linewidth=2, color='r', linestyle = ':')
plt.hlines(y=max_hline, xmin=xmin, xmax=xmax, linewidth=2, color='r', linestyle = ':')
plt.hlines(y=average_hline, xmin=xmin, xmax=xmax, linewidth=2, color='r', linestyle = '-')
plt.vlines(x = xmin, ymin = 0, ymax=20, linewidth=2, color='r', linestyle = ':')
plt.text(xmax, average_hline - 5, '$ '+str(round(average_hline,2))+'\pm '+
         str(round(err,2))+'$ (95% CI)', fontsize = 15, color = 'red', rotation=-90)

xmin, xmax = 0, 20 
min_hline, average_hline, max_hline = confidence_interval(sum_of_subtest[xmin:xmax])
err = average_hline - min_hline
err = average_hline - min_hline
plt.hlines(y=min_hline, xmin=xmin, xmax=xmax, linewidth=2, color='r', linestyle = ':')
plt.hlines(y=max_hline, xmin=xmin, xmax=xmax, linewidth=2, color='r', linestyle = ':')
plt.hlines(y=average_hline, xmin=xmin, xmax=xmax, linewidth=2, color='r', linestyle = '-')
plt.vlines(x = xmax, ymin = 0, ymax=20, linewidth=2, color='r', linestyle = ':')
plt.text(xmax + 1, average_hline - 6, '$ '+str(round(average_hline,2))+'\pm '+
         str(round(err,2))+'$ (95% CI)', fontsize = 15, color = 'red', rotation=-90)
plt.gca().xaxis.label.set_size(15)
plt.gca().yaxis.label.set_size(15)
plt.tick_params(which='major', labelsize=15)
plt.savefig("../../Pictures/Percentage_DbDQN_2.pdf", bbox_inches='tight')
plt.show()

# %%
plt.clf()
df = pd.read_csv("kq_M900_1000_0.9_exlre0.0.csv").values
df = df[:int(df.shape[0]+1),0]
#df_slide_1000 = [df[i:(i+1000)] for i in 299]
df = df.flatten()
df_list = df.tolist()
df_list
data = pd.read_csv("FDQO_5phut_M900_1000_0.9_exlre0.0.csv").values
nb_steps = data[:,5].flatten().tolist()
step = data[:,6].flatten().tolist()
# df_list_splice = [list(df_list[int(i - j): int(i)]) for j in nb_steps for i in step]
# df_list_splice
test = [df_list[int(i - j): int(i)] for j, i in zip(nb_steps, step)]
test.pop(-1) # somehow the last is empty
sum_of_subtest = [sum(sublist) / len(sublist) * 100 for sublist in test]
plt.fill_between([i for i in range(len(sum_of_subtest))], 0, sum_of_subtest)
#plt.title("Percentage of using Fuzzy table (FDQO)")
plt.xlabel("Time slots")
plt.ylabel("%")
plt.axis([0, 100, 0, 100])
plt.xticks([0, 5, 20, 40, 60, 80, 100])

xmin, xmax = 5, 101 
min_hline, average_hline, max_hline = confidence_interval(sum_of_subtest[xmin:xmax])
err = average_hline - min_hline
plt.hlines(y=min_hline, xmin=xmin, xmax=xmax, linewidth=2, color='r', linestyle = ':')
plt.hlines(y=max_hline, xmin=xmin, xmax=xmax, linewidth=2, color='r', linestyle = ':')
plt.hlines(y=average_hline, xmin=xmin, xmax=xmax, linewidth=2, color='r', linestyle = '-')
plt.vlines(x = xmin, ymin = 0, ymax=100, linewidth=2, color='r', linestyle = ':')
plt.text(xmax, 5, '$ '+str(round(average_hline,2))+'\pm '+
         str(round(err,2))+'$ (95% CI)', fontsize = 15, color = 'red', rotation=-90)
plt.gca().xaxis.label.set_size(15)
plt.gca().yaxis.label.set_size(15)
plt.tick_params(which='major', labelsize=15)
plt.savefig("../../Pictures/Percentage_FDQO_0.9_2.pdf", bbox_inches='tight')
plt.show()

# %%
plt.clf()
df = pd.read_csv("kqFDQO_M900_1000_0.85.csv").values
df = df[:int(df.shape[0]+1),0]
#df_slide_1000 = [df[i:(i+1000)] for i in 299]
df = df.flatten()
df_list = df.tolist()
df_list
data = pd.read_csv("FDQO_5phut_M900_1000_0.85.csv").values
nb_steps = data[:,5].flatten().tolist()
step = data[:,6].flatten().tolist()
# df_list_splice = [list(df_list[int(i - j): int(i)]) for j in nb_steps for i in step]
# df_list_splice
test = [df_list[int(i - j): int(i)] for j, i in zip(nb_steps, step)]
test.pop(-1) # somehow the last is empty
sum_of_subtest = [sum(sublist) / len(sublist) * 100 for sublist in test]
plt.fill_between([i for i in range(len(sum_of_subtest))], 0, sum_of_subtest)
#plt.title("Percentage of using Fuzzy table (FDQO)")
plt.xlabel("Time slots")
plt.ylabel("%")
plt.axis([0, 100, 0, 100])
plt.xticks([0, 5, 20, 40, 60, 80, 100])

xmin, xmax = 5, 101 
min_hline, average_hline, max_hline = confidence_interval(sum_of_subtest[xmin:xmax])
err = average_hline - min_hline
plt.hlines(y=min_hline, xmin=xmin, xmax=xmax, linewidth=2, color='r', linestyle = ':')
plt.hlines(y=max_hline, xmin=xmin, xmax=xmax, linewidth=2, color='r', linestyle = ':')
plt.hlines(y=average_hline, xmin=xmin, xmax=xmax, linewidth=2, color='r', linestyle = '-')
plt.vlines(x = xmin, ymin = 0, ymax=100, linewidth=2, color='r', linestyle = ':')
plt.text(xmax, average_hline-22, '$ '+str(round(average_hline,2))+'\pm '+
         str(round(err,2))+'$ (95% CI)', fontsize = 15, color = 'red', rotation=-90)
plt.gca().xaxis.label.set_size(15)
plt.gca().yaxis.label.set_size(15)
plt.tick_params(which='major', labelsize=15)
plt.savefig("../../Pictures/Percentage_FDQO_0.85_2.pdf", bbox_inches='tight')
plt.show()

# %%
plt.clf()
df = pd.read_csv("kq_M900_1000_0.8_exlre0.0.csv").values
df = df[:int(df.shape[0]+1),0]
#df_slide_1000 = [df[i:(i+1000)] for i in 299]
df = df.flatten()
df_list = df.tolist()
df_list
data = pd.read_csv("FDQO_5phut_M900_1000_0.8_exlre0.0.csv").values
nb_steps = data[:,5].flatten().tolist()
step = data[:,6].flatten().tolist()
# df_list_splice = [list(df_list[int(i - j): int(i)]) for j in nb_steps for i in step]
# df_list_splice
test = [df_list[int(i - j): int(i)] for j, i in zip(nb_steps, step)]
test.pop(-1) # somehow the last is empty
sum_of_subtest = [sum(sublist) / len(sublist) * 100 for sublist in test]
plt.fill_between([i for i in range(len(sum_of_subtest))], 0, sum_of_subtest)
#plt.title("Percentage of using Fuzzy table (FDQO)")
plt.xlabel("Time slots")
plt.ylabel("%")
plt.axis([0, 100, 0, 100])
plt.xticks([0, 5, 20, 40, 60, 80, 100])

xmin, xmax = 5, 101 
min_hline, average_hline, max_hline = confidence_interval(sum_of_subtest[xmin:xmax])
err = average_hline - min_hline
plt.hlines(y=min_hline, xmin=xmin, xmax=xmax, linewidth=2, color='r', linestyle = ':')
plt.hlines(y=max_hline, xmin=xmin, xmax=xmax, linewidth=2, color='r', linestyle = ':')
plt.hlines(y=average_hline, xmin=xmin, xmax=xmax, linewidth=2, color='r', linestyle = '-')
plt.vlines(x = xmin, ymin = 0, ymax=100, linewidth=2, color='r', linestyle = ':')
plt.text(xmax, average_hline-21, '$ '+str(round(average_hline,2))+'\pm '+
         str(round(err,2))+'$ (95% CI)', fontsize = 15, color = 'red', rotation=-90)
plt.gca().xaxis.label.set_size(15)
plt.gca().yaxis.label.set_size(15)
plt.tick_params(which='major', labelsize=15)
plt.savefig("../../Pictures/Percentage_FDQO_0.8_2.pdf", bbox_inches='tight')
plt.show()

# %%
import numpy as np

import matplotlib.pyplot as plt

# Generate some data
x = np.linspace(0, 10, 1000)
y = np.sin(np.exp(0.3*x))

fig, ax = plt.subplots()

ax.plot(x, y)

ax.set_ylim(-2,2)

ax.annotate('5', 
            xy=(np.pi/2., 2), 
            xytext=(np.pi/2., 2.3), 
            arrowprops = dict(facecolor='black', shrink=0.05))

plt.show()

# %%
average_hline - min_hline
average_hline
# Out:
# 26.012625720339077

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('default')
import pandas as pd

plt.rcParams['figure.figsize'] = [12, 4]
plt.rcParams['figure.dpi'] = 100 # 200 e.g. is really fine, but slower
# plt.clf()
# number_tasks = pd.read_csv("../../data_task/summary.csv").values
# b = np.arange(200)
# plt.plot(b, number_tasks)
# plt.xlabel("Episode")
# plt.ylabel("Number of tasks")
# plt.axis([0, 100, 0, 2100])
# plt.show()

# plt.clf()
# df = pd.read_csv("kqBDQN_M900_1000_0.1_0.05_b0.6_fix_3.csv").values
# df = df[:int(df.shape[0]+1),0]
# #df_slide_1000 = [df[i:(i+1000)] for i in 299]
# df = df.flatten()
# df_list = df.tolist()
# df_list
# data = pd.read_csv("BDQL_5phut_M900_1000_0.1_0.05_b0.6_fix_3.csv").values
# nb_steps = data[:,5].flatten().tolist()
# step = data[:,6].flatten().tolist()
# # df_list_splice = [list(df_list[int(i - j): int(i)]) for j in nb_steps for i in step]
# # df_list_splice
# test = [df_list[int(i - j): int(i)] for j, i in zip(nb_steps, step)]
# test.pop(-1) # somehow the last is empty
# sum_of_subtest = [sum(sublist) / len(sublist) * 100 for sublist in test]
# plt.fill_between([i + 1 for i in range(len(sum_of_subtest))], 0, sum_of_subtest)
# plt.title("Percentage of exploration (BDQL)")
# plt.xlabel("Time slots")
# plt.ylabel("%")
# plt.axis([0, 100, 0, 20])
# plt.show()

plt.clf()
df = pd.read_csv("kqFDQO_M900_1000_baseline_0.5_dyn_e0.1_k0.3_que3k_b0.5_c0.9.csv").values
df = df[:int(df.shape[0]+1),0]
#df_slide_1000 = [df[i:(i+1000)] for i in 299]
df = df.flatten()
df_list = df.tolist()
df_list
data = pd.read_csv("FDQO_5phut_M900_1000_baseline_0.5_dyn_e0.1_k0.3_que3k_b0.5_c0.9.csv").values
nb_steps = data[:,5].flatten().tolist()
step = data[:,6].flatten().tolist()
# df_list_splice = [list(df_list[int(i - j): int(i)]) for j in nb_steps for i in step]
# df_list_splice
test = [df_list[int(i - j): int(i)] for j, i in zip(nb_steps, step)]
test.pop(-1) # somehow the last is empty
sum_of_subtest = [sum(sublist) / len(sublist) * 100 for sublist in test]
plt.fill_between([i for i in range(len(sum_of_subtest))], 0, sum_of_subtest)
#plt.title("Percentage of using Fuzzy table (b-FDQO)")
plt.xlabel("Time slots")
plt.ylabel("%")
plt.axis([0, 100, 0, 100])
plt.savefig("../../Pictures/Percentage_bFDQO.pdf")
plt.show()

plt.clf()
df = pd.read_csv("kq_M900_1000_0.9_exlre0.0.csv").values
df = df[:int(df.shape[0]+1),0]
#df_slide_1000 = [df[i:(i+1000)] for i in 299]
df = df.flatten()
df_list = df.tolist()
df_list
data = pd.read_csv("FDQO_5phut_M900_1000_0.8_exlre0.0.csv").values
nb_steps = data[:,5].flatten().tolist()
step = data[:,6].flatten().tolist()
# df_list_splice = [list(df_list[int(i - j): int(i)]) for j in nb_steps for i in step]
# df_list_splice
test = [df_list[int(i - j): int(i)] for j, i in zip(nb_steps, step)]
test.pop(-1) # somehow the last is empty
sum_of_subtest = [sum(sublist) / len(sublist) * 100 for sublist in test]
plt.fill_between([i for i in range(len(sum_of_subtest))], 0, sum_of_subtest)
#plt.title("Percentage of using Fuzzy table (FDQO)")
plt.xlabel("Time slots")
plt.ylabel("%")
plt.axis([0, 100, 0, 100])
#plt.savefig("../../Pictures/Percentage_FDQO.pdf")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('default')
import pandas as pd

plt.rcParams['figure.figsize'] = [12, 8]
plt.rcParams['figure.dpi'] = 100 # 200 e.g. is really fine, but slower
plt.yscale('log')

data1 = pd.read_csv("../csvFilesNorm200steps/FDQO_5phut_M900_1000_0.9_baseline0.4_g0.5_queue2k.csv").values[:100, 3]
data2 = pd.read_csv("DDQL_5phut_M900_1000_mem25.csv").values[:100, 3]
data3 = pd.read_csv("DQL_5phut_M900_1000_1_.csv").values[:100, 3]
data5 = pd.read_csv("FDQO_5phut_M900_1000_0.9_exlre0.0.csv").values[:100, 3]
data7 = pd.read_csv("../csvFilesNorm200steps/BDQL_5phut_M900_1000_200steps.csv").values[:100, 3]
number = [i + 1 for i in range(data1.shape[0])]
plt.plot(number, data1, color="green", label = "b-FDQO")
plt.plot(number, data2, color="red", label = "DDQN")
plt.plot(number, data3, color="orange", label = "DQN")
plt.plot(number, data5, color="blue", label = "FDQO")
plt.plot(number, data7, color="purple", label = "Db-DQN") 
plt.axis([1, 100, 0, 20])
plt.legend()
plt.savefig("../../Pictures/MAE_log_scale.pdf")
# Out:
# <ipython-input-13-6f9f24d30d99>:21: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
#   plt.axis([1, 100, 0, 20])

# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
plt.style.use('default')
import pandas as pd

plt.rcParams['figure.figsize'] = [12, 8]
plt.rcParams['figure.dpi'] = 100 # 200 e.g. is really fine, but slower
plt.yscale('log')

data1 = pd.read_csv("../csvFilesNorm200steps/FDQO_5phut_M900_1000_0.9_baseline0.4_g0.5_queue2k.csv").values[:100, 2]
data2 = pd.read_csv("DDQL_5phut_M900_1000_mem25.csv").values[:100, 2]
data3 = pd.read_csv("DQL_5phut_M900_1000_1_.csv").values[:100, 2]
data5 = pd.read_csv("FDQO_5phut_M900_1000_0.9_exlre0.0.csv").values[:100, 2]
data7 = pd.read_csv("../csvFilesNorm200steps/BDQL_5phut_M900_1000_200steps_2.csv").values[:100, 2]
number = [i + 1 for i in range(data1.shape[0])]
plt.plot(number, data1, color="green", label = "b-FDQO")
plt.plot(number, data2, color="red", label = "DDQN")
plt.plot(number, data3, color="orange", label = "DQN")
plt.plot(number, data5, color="blue", label = "FDQO")
plt.plot(number, data7, color="purple", label = "Db-DQN") 
plt.axis([1, 100, 0, 20])
plt.legend()
plt.savefig("../../Pictures/Huber_loss_log_scale.pdf")
# Out:
# <ipython-input-14-459833d9ce3e>:22: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
#   plt.axis([1, 100, 0, 20])

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('default')
import pandas as pd

plt.rcParams['figure.figsize'] = [12, 8]
plt.rcParams['figure.dpi'] = 100 # 200 e.g. is really fine, but slower

data1 = pd.read_csv("FDQO_5phut_M900_1000_baseline_0.5_dyn_e0.1_k0.3_que3k_b0.5_c0.9.csv").values[:100, 2]
data2 = pd.read_csv("DDQL_5phut_M900_1000_mem25.csv").values[:100, 2]
data3 = pd.read_csv("DQL_5phut_M900_1000_1_.csv").values[:100, 2]
data5 = pd.read_csv("FDQO_5phut_M900_1000_0.9_exlre0.0.csv").values[:100, 2]
data7 = pd.read_csv("BDQL_5phut_M900_1000_dyn_e0.1_k0.3_que10k_b0.5.csv").values[:100, 2]
number = [i + 1 for i in range(data4.shape[0])]
plt.plot(number, data1, color="green", label = "b-FDQO")
plt.plot(number, data2, color="red", label = "DDQL")
plt.plot(number, data3, color="orange", label = "DQL")
plt.plot(number, data5, color="blue", label = "FDQO")
plt.plot(number, data7, color="purple", label = "Db-DQL") 
plt.axis([1, 100, 0, 2])
plt.legend()
plt.savefig("../../Pictures/Huber_loss.pdf")

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('default')
import pandas as pd

plt.rcParams['figure.figsize'] = [12, 8]
plt.rcParams['figure.dpi'] = 100 # 200 e.g. is really fine, but slower

def draw_good_average_bad_area_plot(file_path):
    Cov = pd.read_csv(file_path, sep=',', 
                      names=["Good", "Average", "Bad"])
    columns_titles = ["Bad","Average", "Good"]
    df = Cov.divide(Cov.sum(axis=1), axis=0)
    df = df.reindex(columns=columns_titles)
    #df.plot.area(legend = 'reverse', xlim = [0,100], ylim = [0,1])
    df.plot.area(legend = False, xlim = [0,100], ylim = [0,1])
#     plt.legend(ncol = 3)
#     legend = plt.legend(ncol = 3)
#     fig  = legend.figure
#     fig.canvas.draw()
#     bbox  = legend.get_window_extent().transformed(fig.dpi_scale_trans.inverted())
#     fig.savefig("../../Pictures/good_bad_legend.pdf", dpi="figure", bbox_inches=bbox)
    plt.xlabel("Time slots")
    plt.gca().xaxis.label.set_size(15)
    plt.gca().yaxis.label.set_size(15)
    plt.tick_params(which='major', labelsize=15)
    plt.savefig("../../Pictures/n_quality_bfdqo_q2k_2.pdf")
    #plt.savefig("../../Pictures/" + file_path[:-4] + ".pdf")
    #plt.show()
    
#draw_good_average_bad_area_plot("n_quality_tasks_RGreedy_M900_1000.csv")

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('default')
import pandas as pd

plt.rcParams['figure.figsize'] = [12, 8]
plt.rcParams['figure.dpi'] = 100 # 200 e.g. is really fine, but slower

def draw_good_average_bad_area_plot(file_path):
    Cov = pd.read_csv(file_path, sep=',', 
                      names=["Good", "Average", "Bad"])
    columns_titles = ["Bad","Average", "Good"]
    df = Cov.divide(Cov.sum(axis=1), axis=0)
    df = df.reindex(columns=columns_titles)
    #df.plot.area(legend = 'reverse', xlim = [0,100], ylim = [0,1])
    df.plot.area(legend = False, xlim = [0,100], ylim = [0,1])
#     plt.legend(ncol = 3)
#     legend = plt.legend(ncol = 3)
#     fig  = legend.figure
#     fig.canvas.draw()
#     bbox  = legend.get_window_extent().transformed(fig.dpi_scale_trans.inverted())
#     fig.savefig("../../Pictures/good_bad_legend.pdf", dpi="figure", bbox_inches=bbox)
    plt.xlabel("Time slots")
    plt.gca().xaxis.label.set_size(15)
    plt.gca().yaxis.label.set_size(15)
    plt.tick_params(which='major', labelsize=15)
    plt.savefig("../../Pictures/"+file_path[:-4]+".pdf")
    #plt.show()
    
#draw_good_average_bad_area_plot("n_quality_tasks_RGreedy_M900_1000.csv")
#draw_good_average_bad_area_plot("../csvFilesNorm200steps/n_quality_tasks_fdqo_M900_1000_0.9_baseline0.4_g0.5_queue2k.csv")

# %%
import matplotlib.pyplot as plt
plt.clf()
colors = ["crimson", "purple", "gold"]
f = lambda m,c: plt.plot([],[],marker=m, color=c, ls="none")[0]
handles = [f("s", colors[i]) for i in range(3)]
labels = colors
legend = plt.legend(handles, labels, loc=3, framealpha=1, frameon=False)

def export_legend(legend, filename="legend.png"):
    fig  = legend.figure
    fig.canvas.draw()
    bbox  = legend.get_window_extent().transformed(fig.dpi_scale_trans.inverted())
    fig.savefig(filename, dpi="figure", bbox_inches=bbox)

export_legend(legend)
plt.show()

# %%
Cov = pd.read_csv("n_quality_tasks_RGreedy_M900_1000.csv", sep=',', 
                  names=["Good", "Average", "Bad"])
columns_titles = ["Bad","Average", "Good"]
df = Cov.divide(Cov.sum(axis=1), axis=0)
df = df.reindex(columns=columns_titles)

df.plot.area(legend = 'reverse', xlim = [0,100], ylim = [0,1])
plt.savefig("../../Pictures/n_quality_tasks_RGreedy_M900_1000.pdf")

# %%
draw_good_average_bad_area_plot("n_quality_tasks_RGreedy_M900_1000.csv")
draw_good_average_bad_area_plot("n_quality_tasks_dql_M900_1000_mem25_4.csv")
draw_good_average_bad_area_plot("n_quality_tasks_ddql_M900_1000_mem25_3.csv")
draw_good_average_bad_area_plot("n_quality_tasks_bdql_M900_1000_dyn_e0.1_k0.3_que10k_b0.5.csv")
draw_good_average_bad_area_plot("n_quality_tasks_fdqo_M900_1000_0.9_exlre0.0.csv")
#draw_good_average_bad_area_plot("n_quality_tasks_fdqo_M900_1000_baseline_0.5_dyn_e0.1_k0.3_que3k_b0.5_c0.9.csv")

# %%
draw_good_average_bad_area_plot("../csvFilesNorm200steps/n_quality_tasks_fdqo_M900_1000_0.9_baseline0.4_g0.5_queue2k.csv")

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('default')
import pandas as pd

plt.rcParams['figure.figsize'] = [12, 8]
plt.rcParams['figure.dpi'] = 100 # 200 e.g. is really fine, but slower

def good_or_bad_statistic(file_path):
    Cov = pd.read_csv(file_path, sep=',', 
                      names=["Good", "Average", "Bad"])
    columns_titles = ["Bad","Average", "Good"]
    df = Cov.divide(Cov.sum(axis=1), axis=0)
    print(round(df["Good"].mean(), 2), round(df["Bad"].mean(), 2))
good_or_bad_statistic("n_quality_tasks_RGreedy_M900_1000.csv")
good_or_bad_statistic("n_quality_tasks_dql_M900_1000_mem25_4.csv")
good_or_bad_statistic("n_quality_tasks_ddql_M900_1000_mem25_3.csv")
good_or_bad_statistic("n_quality_tasks_bdql_M900_1000_dyn_e0.1_k0.3_que10k_b0.5.csv")
good_or_bad_statistic("n_quality_tasks_fdqo_M900_1000_0.9_exlre0.0.csv")
good_or_bad_statistic("n_quality_tasks_fdqo_M900_1000_baseline_0.5_dyn_e0.1_k0.3_que3k_b0.5_c0.9.csv")
# Out:
# 0.26 0.26
# 0.4 0.22
# 0.41 0.22
# 0.43 0.18
# 0.41 0.25
# 0.42 0.21

# %%
data2 = pd.read_csv("DQL_5phut_M900_1000_mem25_4.csv").values[:100, 1]
data5 = pd.read_csv("DDQL_5phut_M900_1000_mem25_3.csv").values[:100, 1]
data6 = pd.read_csv("BDQL_5phut_M900_1000_0.1_0.05_b0.6_que5000_fix.csv").values[:100, 1]
data7 = pd.read_csv("BDQL_5phut_M900_1000_dyn_e0.1_k0.3_que10k_b0.5.csv").values[:100, 1]

data1 = pd.read_csv("FDQO_5phut_M900_1000_baseline_0.5_dyn_e0.1_k0.3_que3k_b0.5_c0.9.csv").values[:100, 1]
data5 = pd.read_csv("FDQO_5phut_M900_1000_0.9_exlre0.0.csv").values[:100, 1]
data7 = pd.read_csv("BDQL_5phut_M900_1000_dyn_e0.1_k0.3_que10k_b0.5.csv").values[:100, 1]
data8 = pd.read_csv("RGreedy_5phut.csv").values[:100, 2]

# %%
a, b = 5, 70
def statistic(temp):
    print(round(temp.mean(),2), round(temp[0:a].mean(),2), round(temp[b:100].mean(),2),
          round(temp.std(),2), round(temp.min(),2), round(temp.max(),2))
data2 = pd.read_csv("DQL_5phut_M900_1000_mem25_4.csv").values[:100, 1]
data5 = pd.read_csv("DDQL_5phut_M900_1000_mem25_3.csv").values[:100, 1]
statistic(data2)
statistic(data5)
# Out:
# 0.6 0.26 0.63 0.1 0.09 0.79
# 0.61 0.24 0.63 0.12 0.08 0.81

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('default')
import pandas as pd

plt.rcParams['figure.figsize'] = [12, 8]
plt.rcParams['figure.dpi'] = 100 # 200 e.g. is really fine, but slower

data1 = pd.read_csv("n_quality_tasks_dql_0.1_de_0.05_70.csv")
Cov = pd.read_csv("n_quality_tasks_dql_0.1_de_0.05_70.csv", sep=',', 
                  names=["Sequence", "Start", "End"])
print(data1)
print(Cov["Sequence"])
numCov = Cov.values
VsumCov = numCov.sum(axis = 1)
df = Cov.divide(Cov.sum(axis=1), axis=0)
df.plot.area(legend = 'reverse')

columns_titles = ["End","Start", "Sequence"]
df=df.reindex(columns=columns_titles)
print(df)
df.plot.area(legend = 'reverse')
# Out:
#      221   35  896
# 0    258   49  834
# 1    121  105  970
# 2    167   90  942
# 3    231  169  725
# 4    349  145  679
# ..   ...  ...  ...
# 124  332  510  326
# 125  392  475  238
# 126  326  616  248
# 127  401  525  174
# 128  346  447  323
#
# [129 rows x 3 columns]
# 0      221
# 1      258
# 2      121
# 3      167
# 4      231
#       ...
# 125    332
# 126    392
# 127    326
# 128    401
# 129    346
# Name: Sequence, Length: 130, dtype: int64
#           End     Start  Sequence
# 0    0.777778  0.030382  0.191840
# 1    0.730938  0.042945  0.226117
# 2    0.811037  0.087793  0.101171
# 3    0.785655  0.075063  0.139283
# 4    0.644444  0.150222  0.205333
# ..        ...       ...       ...
# 125  0.279110  0.436644  0.284247
# 126  0.215385  0.429864  0.354751
# 127  0.208403  0.517647  0.273950
# 128  0.158182  0.477273  0.364545
# 129  0.289427  0.400538  0.310036
#
# [130 rows x 3 columns]
# <AxesSubplot:>

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('default')
import pandas as pd

plt.rcParams['figure.figsize'] = [12, 6]
plt.rcParams['figure.dpi'] = 100 # 200 e.g. is really fine, but slower
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

a = 5
b = 70
data1 = pd.read_csv("FDQO_5phut_M900_1000_baseline_0.5_dyn_e0.1_k0.3_que3k_b0.5_c0.9.csv").values[:101, 1]
data5 = pd.read_csv("FDQO_5phut_M900_1000_0.9_exlre0.0.csv").values[:101, 1]
data7 = pd.read_csv("BDQL_5phut_M900_1000_dyn_e0.1_k0.3_que10k_b0.5.csv").values[:101, 1]
data8 = pd.read_csv("RGreedy_5phut.csv").values[:101, 2]

# %%
data1['mean_reward']
# Out:
# 0      0.460994
# 1      0.485834
# 2      0.525621
# 3      0.471206
# 4      0.561747
#          ...
# 100    0.517783
# 101    0.463200
# 102    0.479895
# 103    0.576212
# 104    0.584058
# Name: mean_reward, Length: 105, dtype: float64

# %%
df1 = pd.DataFrame(data=data1, columns=["value"])
df5 = pd.DataFrame(data=data5, columns=["value"])
df7 = pd.DataFrame(data=data7, columns=["value"])
df8 = pd.DataFrame(data=data8, columns=["value"])
moving_average_step = 30
df_ma1 = df1.value.rolling(moving_average_step, center=False, closed='left').mean()
df_ma5 = df5.value.rolling(moving_average_step, center=False, closed='left').mean()
df_ma7 = df7.value.rolling(moving_average_step, center=False, closed='left').mean()
df_ma8 = df8.value.rolling(moving_average_step, center=False, closed='left').mean()
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
df_ma1.plot()
df_ma5.plot()
df_ma7.plot()
df_ma8.plot()
plt.axis([30,100,0,1])
# Out:
# (30.0, 100.0, 0.0, 1.0)
