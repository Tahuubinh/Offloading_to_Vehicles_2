# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('dark_background')
import pandas as pd

ddql = pd.read_csv("DDQL_5phut.csv").values
dql = pd.read_csv("DQL_5phut.csv").values

totalddql = ddql[:,0].reshape([-1,1])
meanddql = ddql[:,1].reshape([-1,1])

totaldql = dql[0:99,0].reshape([-1,1])
meandql = dql[0:99,1].reshape([-1,1])
x = [i + 1 for i in range(99)]
x = np.array(x).reshape([-1,1])

#print (meanddql) 
plt.plot(x, meanddql)
plt.plot(x, meandql)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-2a937bedc22a> in <module>
#      16
#      17 #print (meanddql)
# ---> 18 plt.plot(x, meanddql)
#      19 plt.plot(x, meandql)
#      20
#
# D:\Python\Anaconda\envs\Billie\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2792 @docstring.copy(Axes.plot)
#    2793 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2794     return gca().plot(
#    2795         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
#    2796         is not None else {}), **kwargs)
#
# D:\Python\Anaconda\envs\Billie\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1663         """
#    1664         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D._alias_map)
# ...

# %%
# DQL gamma 0.7
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('ggplot')
import pandas as pd

data1 = pd.read_csv("DQL_5phut_1.csv").values[:, 1]
data2 = pd.read_csv("DQL_5phut_2.csv").values[:, 1]
data3 = pd.read_csv("DQL_5phut_3.csv").values[:, 1]
data4 = pd.read_csv("DQL_5phut_4.csv").values[:, 1]
data5 = pd.read_csv("DQL_5phut_5.csv").values[:, 1]

number = [i + 1 for i in range(data1.shape[0])]
plt.tight_layout()
plt.plot(number, data1, color="red")
plt.plot(number, [np.average(data1)] * data1.shape[0], color="red", linestyle = '--')
plt.plot(number, data2, color="green")
plt.plot(number, [np.average(data2)] * data1.shape[0], color="green", linestyle = '--')
plt.plot(number, data3, color="blue")
plt.plot(number, [np.average(data3)] * data1.shape[0], color="blue", linestyle = '--')
#plt.plot(number, data4)
#plt.plot(number, data5)

# %%
# DDQL gamma 0.7
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('ggplot')
import pandas as pd

data1 = pd.read_csv("DDQL_5phut_1.csv").values[:, 1]
data2 = pd.read_csv("DDQL_5phut_2.csv").values[:, 1]
data3 = pd.read_csv("DDQL_5phut_3.csv").values[:, 1]

number = [i + 1 for i in range(data1.shape[0])]
plt.tight_layout()
plt.plot(number, data1, color="red")
plt.plot(number, [np.average(data1)] * data1.shape[0], color="red", linestyle = '--')
plt.plot(number, data2, color="green")
plt.plot(number, [np.average(data2)] * data1.shape[0], color="green", linestyle = '--')
plt.plot(number, data3, color="blue")
plt.plot(number, [np.average(data3)] * data1.shape[0], color="blue", linestyle = '--')

# %%
# FDQO gamma 0.7
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('ggplot')
import pandas as pd

data1 = pd.read_csv("FDQO_5phut_1.csv").values[:, 1]
data2 = pd.read_csv("FDQO_5phut_2.csv").values[:, 1]
data3 = pd.read_csv("FDQO_5phut_3.csv").values[:, 1]

number = [i + 1 for i in range(data1.shape[0])]
plt.tight_layout()
plt.plot(number, data1)
plt.plot(number, data2)
plt.plot(number, data3)

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('ggplot')
import pandas as pd

data1 = pd.read_csv("FDQO_5phut_8.csv").values[:, 1]
#data2 = pd.read_csv("FDQO_5phut_7.csv").values[:, 1]

number = [i + 1 for i in range(data1.shape[0])]
plt.tight_layout()
plt.plot(number, data1)
#plt.plot(number, data2)

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('ggplot')
import pandas as pd

data1 = pd.read_csv("FDQO_5phut_4.csv").values[:, 0]
data2 = pd.read_csv("FDQO_5phut_4.csv").values[:, 2]
data3 = pd.read_csv("FDQO_5phut_4.csv").values[:, 3]
data4 = pd.read_csv("FDQO_5phut_4.csv").values[:, 4]

number = [i + 1 for i in range(data1.shape[0])]
plt.tight_layout()
plt.plot(number, data1, label = 'reward')
plt.plot(number, data2, label = 'loss')
plt.plot(number, data3, label = 'mae')
plt.plot(number, data4, label = 'mean_q')
#plt.plot(number, data2)
plt.legend()

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('ggplot')
import pandas as pd

data1 = pd.read_csv("DQL_5phut_8.csv").values[100:, 1]
data2 = pd.read_csv("DQL_5phut_8.csv").values[100:, 2]
data3 = pd.read_csv("DQL_5phut_8.csv").values[100:, 3]
data4 = pd.read_csv("DQL_5phut_8.csv").values[100:, 4]

number = [i + 100 for i in range(data1.shape[0])]
plt.tight_layout()
plt.plot(number, data1, label = 'mean_reward')
plt.plot(number, data2, label = 'loss')
plt.plot(number, data3, label = 'mae')
plt.plot(number, data4, label = 'mean_q')
#plt.plot(number, data2)
plt.legend()

# %%
# DQL gamma 0.99
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('ggplot')
import pandas as pd

data1 = pd.read_csv("DQL_5phut_6.csv").values[:, 1]
#data2 = pd.read_csv("DDQL_5phut_6.csv").values[:, 1]

number = [i + 1 for i in range(data1.shape[0])]
plt.tight_layout()
plt.plot(number, data1)
#plt.plot(number, data2)

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('ggplot')
import pandas as pd

data1 = pd.read_csv("DQL_5phut_10.csv").values[:, 1]
data2 = pd.read_csv("DQL_5phut_11.csv").values[:, 1]

number = [i + 1 for i in range(data1.shape[0])]
plt.tight_layout()
plt.plot(number, data1)
plt.plot(number, data2)

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('ggplot')
import pandas as pd

data1 = pd.read_csv("DDQL_5phut_10.csv").values[:, 1]
data2 = pd.read_csv("DDQL_5phut_11.csv").values[:, 1]
data3 = pd.read_csv("DDQL_5phut_9.csv").values[:, 1]
data4 = pd.read_csv("DDQL_5phut_8.csv").values[:, 1]

number = [i + 1 for i in range(data1.shape[0])]
plt.tight_layout()
plt.plot(number, data1)
plt.plot(number, data2)
plt.plot(number, data3)
plt.plot(number, data4, label = 'DDQL gamma = 0.8') #other 0.7

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('ggplot')
import pandas as pd

data1 = pd.read_csv("FDQO_5phut_10.csv").values[:, 1]
data2 = pd.read_csv("FDQO_5phut_11.csv").values[:, 1]

number = [i + 1 for i in range(data1.shape[0])]
plt.tight_layout()
plt.plot(number, data1)
plt.plot(number, data2)

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('ggplot')
import pandas as pd

data1 = pd.read_csv("DQL_5phut_15.csv").values[:-40, 1]
#data2 = pd.read_csv("FDQO_5phut_11.csv").values[:, 1]

number = [i + 1 for i in range(data1.shape[0])]
plt.tight_layout()
plt.plot(number, data1)
#plt.plot(number, data2)

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('ggplot')
import pandas as pd

data1 = pd.read_csv("DDQL_5phut_15.csv").values[:-40, 1]
#data2 = pd.read_csv("FDQO_5phut_11.csv").values[:, 1]

number = [i + 1 for i in range(data1.shape[0])]
plt.tight_layout()
plt.plot(number, data1)
#plt.plot(number, data2)

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('ggplot')
import pandas as pd

data1 = pd.read_csv("FDQO_5phut_15.csv").values[:-40, 1]
#data2 = pd.read_csv("FDQO_5phut_11.csv").values[:, 1]

number = [i + 1 for i in range(data1.shape[0])]
plt.tight_layout()
plt.plot(number, data1)
#plt.plot(number, data2)

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('ggplot')
import pandas as pd

begin = 0

data1 = pd.read_csv("DQL_5phut_15.csv").values[begin:, 1]
data2 = pd.read_csv("DQL_5phut_15.csv").values[begin:, 2]
data3 = pd.read_csv("DQL_5phut_15.csv").values[begin:, 3]
data4 = pd.read_csv("DQL_5phut_15.csv").values[begin:, 4]
number = [i for i in range(data1.shape[0])]
plt.tight_layout()
plt.plot(number, data1, label = 'mean_reward')
plt.plot(number, data2, label = 'loss')
plt.plot(number, data3, label = 'mae')
plt.plot(number, data4, label = 'mean_q')
#plt.plot(number, data2)
plt.legend()

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('ggplot')
import pandas as pd

begin = 0

data1 = pd.read_csv("DDQL_5phut_15.csv").values[begin:, 1]
data2 = pd.read_csv("DDQL_5phut_15.csv").values[begin:, 2]
data3 = pd.read_csv("DDQL_5phut_15.csv").values[begin:, 3]
data4 = pd.read_csv("DDQL_5phut_15.csv").values[begin:, 4]
number = [i for i in range(data1.shape[0])]
plt.tight_layout()
plt.plot(number, data1, label = 'mean_reward')
plt.plot(number, data2, label = 'loss')
plt.plot(number, data3, label = 'mae')
plt.plot(number, data4, label = 'mean_q')
#plt.plot(number, data2)
plt.legend()

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('ggplot')
import pandas as pd

begin = 5

data1 = pd.read_csv("FDQO_5phut_15.csv").values[begin:, 1]
data2 = pd.read_csv("FDQO_5phut_15.csv").values[begin:, 2]
data3 = pd.read_csv("FDQO_5phut_15.csv").values[begin:, 3]
data4 = pd.read_csv("FDQO_5phut_15.csv").values[begin:, 4]
number = [i for i in range(data1.shape[0])]
plt.tight_layout()
plt.plot(number, data1, label = 'mean_reward')
plt.plot(number, data2, label = 'loss')
plt.plot(number, data3, label = 'mae')
plt.plot(number, data4, label = 'mean_q')
#plt.plot(number, data2)
plt.legend()

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('ggplot')
import pandas as pd

begin = 5

data1 = pd.read_csv("DQL_5phut_15.csv").values[begin:, 2]
data2 = pd.read_csv("DDQL_5phut_15.csv").values[begin:, 2]
data3 = pd.read_csv("FDQO_5phut_15.csv").values[begin:, 2]
number = [i for i in range(data1.shape[0])]
plt.tight_layout()
plt.plot(number, data1, label = 'DQL')
plt.plot(number, data2, label = 'DDQL')
plt.plot(number, data3, label = 'FDQO')
#plt.plot(number, data2)
plt.title("loss")
plt.legend()

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('ggplot')
import pandas as pd

begin = 5

data1 = pd.read_csv("DQL_5phut_15.csv").values[begin:, 3]
data2 = pd.read_csv("DDQL_5phut_15.csv").values[begin:, 3]
data3 = pd.read_csv("FDQO_5phut_15.csv").values[begin:, 3]
number = [i for i in range(data1.shape[0])]
plt.tight_layout()
plt.plot(number, data1, label = 'DQL')
plt.plot(number, data2, label = 'DDQL')
plt.plot(number, data3, label = 'FDQO')
#plt.plot(number, data2)
plt.title("mae")
plt.legend()

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('ggplot')
import pandas as pd

begin = 5

data1 = pd.read_csv("DQL_5phut_15.csv").values[begin:, 4]
data2 = pd.read_csv("DDQL_5phut_15.csv").values[begin:, 4]
data3 = pd.read_csv("FDQO_5phut_15.csv").values[begin:, 4]
number = [i for i in range(data1.shape[0])]
plt.tight_layout()
plt.plot(number, data1, label = 'DQL')
plt.plot(number, data2, label = 'DDQL')
plt.plot(number, data3, label = 'FDQO')
#plt.plot(number, data2)
plt.title("mean_q")
plt.legend()

# %%
import pandas as pd
df = pd.read_csv("kq.csv").values
df
print('fuzzy', np.sum(df))
df.shape[0]
# Out:
# fuzzy 80753
# 300285

# %%
import numpy as np
import gym

from keras.models import Sequential
from keras.layers import Dense, Activation, Flatten
from keras.optimizers import Adam

from rl.agents.dqn import DQNAgent
from rl.policy import EpsGreedyQPolicy
from rl.memory import SequentialMemory

ENV_NAME = 'CartPole-v0'

# Get the environment and extract the number of actions available in the Cartpole problem
env = gym.make(ENV_NAME)
np.random.seed(123)
env.seed(123)
nb_actions = env.action_space.n


model = Sequential()
model.add(Flatten(input_shape=(1,) + env.observation_space.shape))
model.add(Dense(16))
model.add(Activation('relu'))
model.add(Dense(nb_actions))
model.add(Activation('linear'))
print(model.summary())

policy = EpsGreedyQPolicy()
memory = SequentialMemory(limit=50000, window_length=1)
dqn = DQNAgent(model=model, nb_actions=nb_actions, memory=memory, nb_steps_warmup=10,
target_model_update=1e-2, policy=policy)
dqn.compile(Adam(lr=1e-3), metrics=['mae'])

# Okay, now it's time to learn something! We visualize the training here for show, but this slows down training quite a lot. 
dqn.fit(env, nb_steps=50000, visualize=False, verbose=2)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# flatten (Flatten)            (None, 4)                 0
# _________________________________________________________________
# dense (Dense)                (None, 16)                80
# _________________________________________________________________
# activation (Activation)      (None, 16)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 34
# _________________________________________________________________
# activation_1 (Activation)    (None, 2)                 0
# ...
# Total params: 114
# Trainable params: 114
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training for 50000 steps ...
# ...

# %%
dqn.test(env, nb_episodes=5, visualize=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-a752a16962fe> in <module>
# ----> 1 dqn.test(env, nb_episodes=5, visualize=True)
#
# NameError: name 'dqn' is not defined
