# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('default')
import pandas as pd
plt.rcParams['figure.figsize'] = [12, 6]
plt.rcParams['figure.dpi'] = 100 # 200 e.g. is really fine, but slower
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
plt.tight_layout()

# %%
a = 0
b = 100
folder_name1 = "DQN5" + '/'
folder_name2 = "DDQN5" + '/'
folder_name3 = "DuelingDQN3" + '/'
folder_name4 = "DoubleDuelingDQN1" + '/'
folder_name5 = "DQN5_no_energy" + '/'
folder_name6 = "DDQN5_no_energy" + '/'
folder_name7 = "DuelingDQN3_no_energy" + '/'
folder_name8 = "DQN2" + '/'
folder_nameR0 = "Random_0_1_1_1_1_1" + '/'
folder_nameR1 = "Random_1_1_1_1_1_1" + '/'
folder_nameR2 = "Random_2_1_1_1_1_1" + '/'
folder_nameR3 = "Random_3_1_1_1_1_1" + '/'
folder_nameR4 = "Random_4_1_1_1_1_1" + '/'
folder_nameR5 = "Random_5_1_1_1_1_1" + '/'

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('default')
import pandas as pd
from scipy.interpolate import make_interp_spline

plt.rcParams['figure.figsize'] = [12, 6]
plt.rcParams['figure.dpi'] = 100 # 200 e.g. is really fine, but slower
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

a = 5
b = 170

data1 = pd.read_csv("result1/DQN/1/cb_5phut.csv").values[:201, 1]
number = np.asarray([i for i in range(data1.shape[0])])
for i in range(1, 10):
    data1 = pd.read_csv("result1/BFDQO_b_0.6_k_0.8_e_0.12/"+str(i)+"/cb_5phut.csv").values[:201, 1]
    X_Y_Spline = make_interp_spline(number, data1)
    X_ = np.linspace(number.min(), number.max(), 200)
    Y_ = X_Y_Spline(X_)
    ax.plot(X_, Y_, color="blue")
    Baverage1 = np.average(data1[0:a])
    Waverage1 = np.average(data1[0:200])
    Laverage1 = np.average(data1[b:200])
    
# number = np.asarray([i for i in range(data1.shape[0])])
# X_Y_Spline = make_interp_spline(number, data1)
# X_ = np.linspace(number.min(), number.max(), 200)
# Y_ = X_Y_Spline(X_)
# ax.plot(X_, Y_, color=str(111111 * i), label = "FDQO")
# Baverage1 = np.average(data1[0:a])
# Waverage1 = np.average(data1[0:200])
# Laverage1 = np.average(data1[b:100])

plt.xlabel("Time slots")
plt.ylabel("Average QoE")
# plt.xticks(np.arange(0, 101, 5.0))
# plt.axis([0, 100, 0, 1])
ax.axis([0, 200, 0, 1])
major_ticks = np.arange(0, 201, 20)
minor_ticks = np.arange(0, 201, 5)

ax.set_xticks(major_ticks)
ax.set_xticks(minor_ticks, minor=True)
ax.set_yticks(np.arange(0,1.05,0.2))
ax.set_yticks(np.arange(0,1.05,0.05), minor=True)

ax.grid(which='both')

# Or if you want different settings for the grids:
ax.grid(which='minor', alpha=0.2)
ax.grid(which='major', alpha=0.5)
#plt.savefig("../../Pictures/bFDQO_vs_others_200tslots_2.pdf")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('default')
import pandas as pd
from scipy.interpolate import make_interp_spline

plt.rcParams['figure.figsize'] = [12, 6]
plt.rcParams['figure.dpi'] = 100 # 200 e.g. is really fine, but slower
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

a = 5
b = 170

# %%
alg = "DQN"
datat = pd.read_csv("result1/" + alg + "/"+str(1)+"/cb_5phut.csv").values[:201, 1]
for i in range(2, 11):
    datat += pd.read_csv("result1/" + alg + "/"+str(i)+"/cb_5phut.csv").values[:201, 1]    
datat /= 10
data2 = datat

alg = "DDQN"
datat = pd.read_csv("result1/" + alg + "/"+str(1)+"/cb_5phut.csv").values[:201, 1]
for i in range(2, 11):
    datat += pd.read_csv("result1/" + alg + "/"+str(i)+"/cb_5phut.csv").values[:201, 1]    
datat /= 10
data5 = datat

alg = "Sb-DQN"
datat = pd.read_csv("result1/" + alg + "/"+str(1)+"/cb_5phut.csv").values[:201, 1]
for i in range(2, 11):
    datat += pd.read_csv("result1/" + alg + "/"+str(i)+"/cb_5phut.csv").values[:201, 1]    
datat /= 10
data6 = datat

alg = "Db-DQN_b_0.55_k_0.6_e_0.12"
datat = pd.read_csv("result1/" + alg + "/"+str(1)+"/cb_5phut.csv").values[:201, 1]
for i in range(2, 11):
    datat += pd.read_csv("result1/" + alg + "/"+str(i)+"/cb_5phut.csv").values[:201, 1]    
datat /= 10
data7 = datat
#data7 = pd.read_csv("result1/Temp/5/cb_5phut.csv").values[:201, 1]

# %%
1 - Baverage2/Baverage7, Waverage7/Waverage2, Laverage7/Laverage2
# Out:
# (0.15228120581255522, 1.0596479518185642, 1.0429171548321745)

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('default')
import pandas as pd

plt.rcParams.update({'font.size': 14})
plt.rcParams['figure.figsize'] = [12, 6]
plt.rcParams['figure.dpi'] = 100 # 200 e.g. is really fine, but slower
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

a = 5
b = 70
number = [i for i in range(data2.shape[0])]
# plt.plot(number, data1, color="gray", label = "Greedy")
# Baverage1 = np.average(data1[0:a])
# Waverage1 = np.average(data1[0:100])
# Laverage1 = np.average(data1[b:100])
#plt.plot(number, [np.average(data1[a:b])] * data2.shape[0], color="red", linestyle = '--')
ax.plot(number, data2, color="red", label = "DQN")
Baverage2 = np.average(data2[0:a])
Waverage2 = np.average(data2[0:100])
Laverage2 = np.average(data2[b:100])
#plt.plot(number, [np.average(data2[a:b])] * data2.shape[0], color="red", linestyle = '--')
ax.plot(number, data5, color="orange", label = "DDQN")
Baverage5 = np.average(data5[0:a])
Waverage5 = np.average(data5[0:100])
Laverage5 = np.average(data5[b:100])
#plt.plot(number, [np.average(data5[a:b])] * data2.shape[0], color="blue", linestyle = '--')
# plt.plot(number, data55, color="blue", label = "DDQL under", linestyle = '-.')
# plt.plot(number, [np.average(data55[a:b])] * data55.shape[0], color="blue", linestyle = ':')
ax.plot(number, data6, color="blueviolet", label = "Sb-DQN")
Baverage6 = np.average(data6[0:a])
Waverage6 = np.average(data6[0:100])
Laverage6 = np.average(data6[b:100])
#plt.plot(number, [np.average(data6[a:b])] * data6.shape[0], color="green", linestyle = '--')
ax.plot(number, data7, color="limegreen", label = "Db-DQN")
Baverage7 = np.average(data7[0:a])
Waverage7 = np.average(data7[0:100])
Laverage7 = np.average(data7[b:100])

# ax.plot(number, data8, color="pink", label = "Sarsa")
# Baverage8 = np.average(data8[0:a])
# Waverage8 = np.average(data8[0:100])
# Laverage8 = np.average(data8[b:100])
# plt.plot(number, data9, color="purple", label = "DQL base 0.2")
# plt.plot(number, [np.average(data9[a:b])] * data6.shape[0], color="purple", linestyle = '--')
# plt.plot(number, data10, color="gray", label = "DQL base 0.2 with 0.05 exp")
# plt.plot(number, [np.average(data10[a:b])] * data6.shape[0], color="gray", linestyle = '--')
#plt.title("900 - 1000 tasks per episode, average: " + str(a) + " - " + str(b))
plt.xlabel("Time slots")
plt.ylabel("Average QoE")
plt.legend(ncol=2, fancybox=True, shadow=True)
# plt.xticks(np.arange(0, 101, 5.0))
# plt.axis([0, 100, 0, 1])
# plt.grid()
ax.axis([0, 100, 0, 1])
major_ticks = np.arange(0, 101, 20)
minor_ticks = np.arange(0, 101, 5)

ax.set_xticks(major_ticks)
ax.set_xticks(minor_ticks, minor=True)
ax.set_yticks(np.arange(0,1.05,0.2))
ax.set_yticks(np.arange(0,1.05,0.05), minor=True)

ax.grid(which='both')

# Or if you want different settings for the grids:
ax.grid(which='minor', alpha=0.2)
ax.grid(which='major', alpha=0.5)
#plt.savefig("../Pictures/No_Fuzzy_Algos.pdf")
plt.show()

plt.clf()
df = pd.DataFrame({
    '': ['DQN', 'DDQN', 'Sb-DQN', 'Db-DQN'],
    'Average QoE of the first '+str(a)+' time slots': [Baverage2, Baverage5, Baverage6, Baverage7],
    'Average QoE of all time slots': [Waverage2, Waverage5, Waverage6, Waverage7],
    'Average QoE of the last '+str(100-b)+' time slots': [Laverage2, Laverage5, Laverage6, Laverage7]
})

# plotting graph
df.plot.bar(x="", y=["Average QoE of the first "+str(a)+" time slots", "Average QoE of all time slots", 
                     "Average QoE of the last "+str(100-b)+" time slots"], color={"Average QoE of the first "+str(a)+" time slots": "red",
                     "Average QoE of all time slots": "green", "Average QoE of the last "+str(100-b)+" time slots": "blue"},
                     ylim = [0, 1], rot = 0)
plt.ylabel("Average QoE")
plt.grid()
plt.plot([-1,1,2,4], [max(df['Average QoE of the first '+str(a)+' time slots'])] * 4, color="red", linestyle = '--')
plt.plot([-1,1,2,4], [max(df['Average QoE of all time slots'])] * 4, color="green", linestyle = '--')
plt.plot([-1,1,2,4], [max(df['Average QoE of the last '+str(100-b)+' time slots'])] * 4, color="blue", linestyle = '--')
#plt.savefig("../Pictures/No_Fuzzy_Algos_Statistic_2.pdf")

# %%
alg = "Db-DQN_b_0.55_k_0.6_e_0.12"
datat = pd.read_csv("result1/" + alg + "/"+str(1)+"/cb_5phut.csv").values[:201, 1]
for i in range(2, 11):
    datat += pd.read_csv("result1/" + alg + "/"+str(i)+"/cb_5phut.csv").values[:201, 1]    
datat /= 10
data2 = datat

alg = "b-FDQO_b_0.5_k_0.6_e_0.12"
datat = pd.read_csv("result1/" + alg + "/"+str(1)+"/cb_5phut.csv").values[:201, 1]
for i in range(2, 11):
    datat += pd.read_csv("result1/" + alg + "/"+str(i)+"/cb_5phut.csv").values[:201, 1]    
datat /= 10
data3 = datat

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('default')
import pandas as pd
from scipy.interpolate import make_interp_spline

plt.rcParams.update({'font.size': 14})
plt.rcParams['figure.figsize'] = [12, 6]
plt.rcParams['figure.dpi'] = 100 # 200 e.g. is really fine, but slower
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

a = 5
b = 70
data1 = pd.read_csv("result1/Ver1_Alg_result/FDQO_5phut_M900_1000_0.9_200steps.csv").values[:201, 1]
# data2 = pd.read_csv("BDQL_5phut_M900_1000_200steps_gamma_0.9.csv").values[:200, 1]
# data3 = pd.read_csv("FDQO_5phut_M900_1000_0.9_baseline0.4_g0.5_queue2k.csv").values[:201, 1]
data4 = pd.read_csv("result1/RGreedy/1/RGreedy_5phut.csv").values[:201, 2]
number = np.asarray([i for i in range(data1.shape[0])])
X_Y_Spline = make_interp_spline(number, data1)
X_ = np.linspace(number.min(), number.max(), 200)
Y_ = X_Y_Spline(X_)
ax.plot(X_, Y_, color="red", label = "FDQO")
Baverage1 = np.average(data1[0:a])
Waverage1 = np.average(data1[0:200])
Laverage1 = np.average(data1[b:100])

X_Y_Spline = make_interp_spline(number, data2)
X_ = np.linspace(number.min(), number.max(), 200)
Y_ = X_Y_Spline(X_)
# plt.plot(number, [np.average(data2[a:b])] * data2.shape[0], color="red", linestyle = '--')
ax.plot(X_, Y_, color="blue", label = "Db-DQN")
Baverage2 = np.average(data2[0:a])
Waverage2 = np.average(data2[0:200])
Laverage2 = np.average(data2[b:100])

X_Y_Spline = make_interp_spline(number, data3)
X_ = np.linspace(number.min(), number.max(), 200)
Y_ = X_Y_Spline(X_)
# plt.plot(number, [np.average(data2[a:b])] * data2.shape[0], color="red", linestyle = '--')
ax.plot(X_, Y_, color="green", label = "b-FDQO")
# Baverage7 = np.average(data7[0:a])
# Waverage7 = np.average(data7[0:100])
# Laverage7 = np.average(data7[b:100])
# # plt.plot(number, [np.average(data6[a:b])] * data6.shape[0], color="purple", linestyle = '--')
ax.plot(number, data4, color="gray", label = "Greedy")
# Baverage8 = np.average(data8[0:a])
# Waverage8 = np.average(data8[0:100])
# Laverage8 = np.average(data8[b:100])

plt.xlabel("Time slots")
plt.ylabel("Average QoE")
plt.legend(fancybox=True, shadow=True)
# plt.xticks(np.arange(0, 101, 5.0))
# plt.axis([0, 100, 0, 1])
ax.axis([0, 200, 0, 1])
major_ticks = np.arange(0, 201, 20)
minor_ticks = np.arange(0, 201, 5)

ax.set_xticks(major_ticks)
ax.set_xticks(minor_ticks, minor=True)
ax.set_yticks(np.arange(0,1.05,0.2))
ax.set_yticks(np.arange(0,1.05,0.05), minor=True)

ax.grid(which='both')

# Or if you want different settings for the grids:
ax.grid(which='minor', alpha=0.2)
ax.grid(which='major', alpha=0.5)
plt.savefig("../Pictures/bFDQO_vs_others_200tslots_2.pdf")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('default')
import pandas as pd
from scipy.interpolate import make_interp_spline

plt.rcParams.update({'font.size': 14})
plt.rcParams['figure.figsize'] = [12, 6]
plt.rcParams['figure.dpi'] = 100 # 200 e.g. is really fine, but slower
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

#data1 = pd.read_csv("FDQO_5phut_M900_1000_200steps_g0.9.csv").values[:201, 1]
data1 = pd.read_csv("result1/Ver1_Alg_result/FDQO_5phut_M900_1000_0.9_200steps.csv").values[:201, 1]
# data2 = pd.read_csv("BDQL_5phut_M900_1000_200steps_gamma_0.9.csv").values[:201, 1]
# data3 = pd.read_csv("FDQO_5phut_M900_1000_0.9_baseline0.4_g0.5_queue2k.csv").values[:201, 1]
# data4 = pd.read_csv("FDQO_5phut_M900_1000_0.9_g0.7.csv.csv").values[:201, 1]
# data5 = pd.read_csv("FDQO_5phut_M900_1000_200steps_g0.9.csv").values[:201, 1]
# data6 = pd.read_csv("FDQO_5phut_M900_1000_0.9_g0.6.csv").values[:201, 1]
# data61 = pd.read_csv("../First5timeslots/FDQO_5phut_M900_1000_0.9_g0.5.csv").values[:201, 1]
data7 = pd.read_csv("result1/RGreedy/1/RGreedy_5phut.csv").values[:201, 2]
number = [i for i in range(data1.shape[0])]
moving_average_step = 40
df2 = pd.DataFrame(data=data2, columns=["value"])
df_ma2 = df2.value.rolling(moving_average_step, center=False, closed='left').mean()
df_ma2.plot(color="blue", label = "Db-DQN")
df3 = pd.DataFrame(data=data3, columns=["value"])
df_ma3 = df3.value.rolling(moving_average_step, center=False, closed='left').mean()
df_ma3.plot(color="green", label = "b-FDQO")
# df61 = pd.DataFrame(data=data61, columns=["value"])
# df_ma61 = df61.value.rolling(moving_average_step, center=False, closed='left').mean()
# df_ma61.plot(color="black", label = "FDQO $\gamma = 0.5$")
# df6 = pd.DataFrame(data=data6, columns=["value"])
# df_ma6 = df6.value.rolling(moving_average_step, center=False, closed='left').mean()
# df_ma6.plot(color="violet", label = "FDQO $\gamma = 0.6$")

# df4 = pd.DataFrame(data=data4, columns=["value"])
# df_ma4 = df4.value.rolling(moving_average_step, center=False, closed='left').mean()
# df_ma4.plot(color="orange", label = "FDQO $\gamma = 0.7$")
df1 = pd.DataFrame(data=data1, columns=["value"])
df_ma1 = df1.value.rolling(moving_average_step, center=False, closed='left').mean()
df_ma1.plot(color="red", label = "FDQO")
# df5 = pd.DataFrame(data=data5, columns=["value"])
# df_ma5 = df5.value.rolling(moving_average_step, center=False, closed='left').mean()
# df_ma5.plot(color="purple", label = "FDQO $\gamma = 0.9$")
df7 = pd.DataFrame(data=data7, columns=["value"])
df_ma7 = df7.value.rolling(moving_average_step, center=False, closed='left').mean()
df_ma7.plot(color="gray", label = "Greedy")
plt.xlabel("Time slots")
plt.ylabel("Average QoE")
plt.legend(fancybox=True, shadow=True)
# plt.xticks(np.arange(0, 101, 5.0))
# plt.axis([0, 100, 0, 1])
ax.axis([moving_average_step, 100, 0.5, 0.75])
major_ticks = np.arange(moving_average_step, 201, 10)
minor_ticks = np.arange(moving_average_step, 201, 5)

ax.set_xticks(major_ticks)
ax.set_xticks(minor_ticks, minor=True)
ax.set_yticks(np.arange(0.5,0.8,0.05))
ax.set_yticks(np.arange(0.5,0.8,0.05), minor=True)

ax.grid(which='both')

# Or if you want different settings for the grids:
ax.grid(which='minor', alpha=0.2)
ax.grid(which='major', alpha=0.5)
plt.savefig("../Pictures/bFDQO_200tslots_vs_others_moving_average_not_gamma.pdf")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('default')
import pandas as pd
from scipy.interpolate import make_interp_spline

plt.rcParams['figure.figsize'] = [12, 6]
plt.rcParams['figure.dpi'] = 100 # 200 e.g. is really fine, but slower
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

#data1 = pd.read_csv("FDQO_5phut_M900_1000_200steps_g0.9.csv").values[:201, 1]
data1 = pd.read_csv("FDQO_5phut_M900_1000_0.9_200steps.csv").values[:201, 1]
data2 = pd.read_csv("BDQL_5phut_M900_1000_200steps_gamma_0.9.csv").values[:201, 1]
data3 = pd.read_csv("FDQO_5phut_M900_1000_0.9_baseline0.4_g0.5_queue2k.csv").values[:201, 1]
data4 = pd.read_csv("FDQO_5phut_M900_1000_0.9_g0.7.csv.csv").values[:201, 1]
data5 = pd.read_csv("FDQO_5phut_M900_1000_200steps_g0.9.csv").values[:201, 1]
data6 = pd.read_csv("FDQO_5phut_M900_1000_0.9_g0.6.csv").values[:201, 1]
data61 = pd.read_csv("../First5timeslots/FDQO_5phut_M900_1000_0.9_g0.5.csv").values[:201, 1]
data7 = pd.read_csv("RGreedy_5phut.csv").values[:201, 2]
number = [i for i in range(data1.shape[0])]
moving_average_step = 40
df2 = pd.DataFrame(data=data2, columns=["value"])
df_ma2 = df2.value.rolling(moving_average_step, center=False, closed='left').mean()
df_ma2.plot(color="blue", label = "Db-DQN")
df3 = pd.DataFrame(data=data3, columns=["value"])
df_ma3 = df3.value.rolling(moving_average_step, center=False, closed='left').mean()
df_ma3.plot(color="green", label = "b-FDQO")
# df61 = pd.DataFrame(data=data61, columns=["value"])
# df_ma61 = df61.value.rolling(moving_average_step, center=False, closed='left').mean()
# df_ma61.plot(color="black", label = "FDQO $\gamma = 0.5$")
# df6 = pd.DataFrame(data=data6, columns=["value"])
# df_ma6 = df6.value.rolling(moving_average_step, center=False, closed='left').mean()
# df_ma6.plot(color="violet", label = "FDQO $\gamma = 0.6$")

# df4 = pd.DataFrame(data=data4, columns=["value"])
# df_ma4 = df4.value.rolling(moving_average_step, center=False, closed='left').mean()
# df_ma4.plot(color="orange", label = "FDQO $\gamma = 0.7$")
df1 = pd.DataFrame(data=data1, columns=["value"])
df_ma1 = df1.value.rolling(moving_average_step, center=False, closed='left').mean()
df_ma1.plot(color="red", label = "FDQO")
# df5 = pd.DataFrame(data=data5, columns=["value"])
# df_ma5 = df5.value.rolling(moving_average_step, center=False, closed='left').mean()
# df_ma5.plot(color="purple", label = "FDQO $\gamma = 0.9$")
df7 = pd.DataFrame(data=data7, columns=["value"])
df_ma7 = df7.value.rolling(moving_average_step, center=False, closed='left').mean()
df_ma7.plot(color="gray", label = "Greedy")
plt.xlabel("Time slots")
plt.ylabel("Average QoE")
plt.legend(fancybox=True, shadow=True)
# plt.xticks(np.arange(0, 101, 5.0))
# plt.axis([0, 100, 0, 1])
ax.axis([moving_average_step, 100, 0.5, 0.75])
major_ticks = np.arange(moving_average_step, 201, 10)
minor_ticks = np.arange(moving_average_step, 201, 5)

ax.set_xticks(major_ticks)
ax.set_xticks(minor_ticks, minor=True)
ax.set_yticks(np.arange(0.5,0.8,0.05))
ax.set_yticks(np.arange(0.5,0.8,0.05), minor=True)

ax.grid(which='both')

# Or if you want different settings for the grids:
ax.grid(which='minor', alpha=0.2)
ax.grid(which='major', alpha=0.5)
#plt.savefig("../../Pictures/bFDQO_200tslots_vs_others_moving_average_not_gamma.pdf")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('default')
import pandas as pd
from scipy.interpolate import make_interp_spline

plt.rcParams['figure.figsize'] = [12, 6]
plt.rcParams['figure.dpi'] = 100 # 200 e.g. is really fine, but slower
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

#data1 = pd.read_csv("FDQO_5phut_M900_1000_200steps_g0.9.csv").values[:201, 1]
data1 = pd.read_csv("FDQO_5phut_M900_1000_0.9_200steps.csv").values[:201, 1]
data2 = pd.read_csv("BDQL_5phut_M900_1000_200steps_gamma_0.9.csv").values[:201, 1]
data3 = pd.read_csv("FDQO_5phut_M900_1000_0.9_baseline0.4_g0.5_queue2k.csv").values[:201, 1]
data4 = pd.read_csv("FDQO_5phut_M900_1000_0.9_g0.7.csv.csv").values[:201, 1]
data5 = pd.read_csv("FDQO_5phut_M900_1000_200steps_g0.9.csv").values[:201, 1]
data6 = pd.read_csv("FDQO_5phut_M900_1000_0.9_g0.6.csv").values[:201, 1]
data61 = pd.read_csv("../First5timeslots/FDQO_5phut_M900_1000_0.9_g0.5.csv").values[:201, 1]
data7 = pd.read_csv("RGreedy_5phut.csv").values[:201, 2]
number = [i for i in range(data1.shape[0])]
moving_average_step = 40
df2 = pd.DataFrame(data=data2, columns=["value"])
df_ma2 = df2.value.rolling(moving_average_step, center=False, closed='left').mean()
df_ma2.plot(color="blue", label = "Db-DQN")
df3 = pd.DataFrame(data=data3, columns=["value"])
df_ma3 = df3.value.rolling(moving_average_step, center=False, closed='left').mean()
df_ma3.plot(color="green", label = "b-FDQO")
# df61 = pd.DataFrame(data=data61, columns=["value"])
# df_ma61 = df61.value.rolling(moving_average_step, center=False, closed='left').mean()
# df_ma61.plot(color="black", label = "FDQO $\gamma = 0.5$")
# df6 = pd.DataFrame(data=data6, columns=["value"])
# df_ma6 = df6.value.rolling(moving_average_step, center=False, closed='left').mean()
# df_ma6.plot(color="violet", label = "FDQO $\gamma = 0.6$")

# df4 = pd.DataFrame(data=data4, columns=["value"])
# df_ma4 = df4.value.rolling(moving_average_step, center=False, closed='left').mean()
# df_ma4.plot(color="orange", label = "FDQO $\gamma = 0.7$")
df1 = pd.DataFrame(data=data1, columns=["value"])
df_ma1 = df1.value.rolling(moving_average_step, center=False, closed='left').mean()
df_ma1.plot(color="red", label = "FDQO")
# df5 = pd.DataFrame(data=data5, columns=["value"])
# df_ma5 = df5.value.rolling(moving_average_step, center=False, closed='left').mean()
# df_ma5.plot(color="purple", label = "FDQO $\gamma = 0.9$")
df7 = pd.DataFrame(data=data7, columns=["value"])
df_ma7 = df7.value.rolling(moving_average_step, center=False, closed='left').mean()
df_ma7.plot(color="gray", label = "Greedy")
plt.xlabel("Time slots")
plt.ylabel("Average QoE")
plt.legend(fancybox=True, shadow=True)
# plt.xticks(np.arange(0, 101, 5.0))
# plt.axis([0, 100, 0, 1])
ax.axis([moving_average_step, 100, 0.5, 0.75])
major_ticks = np.arange(moving_average_step, 201, 10)
minor_ticks = np.arange(moving_average_step, 201, 5)

ax.set_xticks(major_ticks)
ax.set_xticks(minor_ticks, minor=True)
ax.set_yticks(np.arange(0.5,0.8,0.05))
ax.set_yticks(np.arange(0.5,0.8,0.05), minor=True)

ax.grid(which='both')

# Or if you want different settings for the grids:
ax.grid(which='minor', alpha=0.2)
ax.grid(which='major', alpha=0.5)
#plt.savefig("../../Pictures/bFDQO_200tslots_vs_others_moving_average_not_gamma.pdf")
plt.show()

# %%
alg = "b-FDQO_b_0.5_k_0.6_e_0.12"

datat = pd.read_csv("result1/" + alg + "/"+str(1)+"/kqFDQO.csv").values[:, :].astype(np.float32)
for i in range(2, 11):
    datat += pd.read_csv("result1/" + alg + "/"+str(i)+"/kqFDQO.csv").values[:, :].astype(np.float32)  
datat /= 10
data2 = datat

datat = pd.read_csv("result1/" + alg + "/"+str(1)+"/cb_5phut.csv").values[:201, :]
for i in range(2, 11):
    datat += pd.read_csv("result1/" + alg + "/"+str(i)+"/cb_5phut.csv").values[:201, :]    
datat /= 10
data3 = datat

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('default')
import pandas as pd

plt.rcParams.update({'font.size': 14})
plt.rcParams['figure.figsize'] = [12, 5]

df = data2
df = df[:int(df.shape[0]+1),0]
#df_slide_1000 = [df[i:(i+1000)] for i in 299]
df = df.flatten()
df_list = df.tolist()

data = data3
nb_steps = data[:,5].flatten().tolist()
step = data[:,6].flatten().tolist()
# df_list_splice = [list(df_list[int(i - j): int(i)]) for j in nb_steps for i in step]
# df_list_splice
test = [df_list[int(i - j): int(i)] for j, i in zip(nb_steps, step)]
test.pop(-1) # somehow the last is empty
# for sublist in test:
#     print(sublist)
sum_of_subtest = [sum(sublist) / len(sublist) * 100 for sublist in test]
plt.fill_between([i for i in range(len(sum_of_subtest))], 0, sum_of_subtest)
#plt.title("Percentage of using Fuzzy table (FDQO)")
plt.xlabel("Time slots")
plt.ylabel("%")
plt.axis([0, 200, 0, 100])
plt.savefig("../Pictures/Percentage_bFDQO_200tslots.pdf")
plt.show()

# %%
alg = "DQN_5k"
datat = pd.read_csv("result1/" + alg + "/"+str(1)+"/cb_5phut.csv").values[:5, 1]
for i in range(2, 31):
    datat += pd.read_csv("result1/" + alg + "/"+str(i)+"/cb_5phut.csv").values[:5, 1]    
datat /= 30
dqn = datat

alg = "DDQN_5k"
datat = pd.read_csv("result1/" + alg + "/"+str(1)+"/cb_5phut.csv").values[:5, 1]
for i in range(2, 31):
    datat += pd.read_csv("result1/" + alg + "/"+str(i)+"/cb_5phut.csv").values[:5, 1]    
datat /= 30
ddqn = datat

alg = "Sb-DQN_5k"
datat = pd.read_csv("result1/" + alg + "/"+str(1)+"/cb_5phut.csv").values[:5, 1]
for i in range(2, 31):
    datat += pd.read_csv("result1/" + alg + "/"+str(i)+"/cb_5phut.csv").values[:5, 1]    
datat /= 30
sta = datat

alg = "Db-DQN_5k"
datat = pd.read_csv("result1/" + alg + "/"+str(1)+"/cb_5phut.csv").values[:5, 1]
for i in range(2, 31):
    datat += pd.read_csv("result1/" + alg + "/"+str(i)+"/cb_5phut.csv").values[:5, 1]    
datat /= 30
dyn = datat
#data7 = pd.read_csv("result1/Temp/5/cb_5phut.csv").values[:201, 1]

alg = "b-FDQO_5k"
datat = pd.read_csv("result1/" + alg + "/"+str(1)+"/cb_5phut.csv").values[:5, 1]
for i in range(2, 31):
    datat += pd.read_csv("result1/" + alg + "/"+str(i)+"/cb_5phut.csv").values[:5, 1]    
datat /= 30
bfdqo = datat

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd 

parameters = {'axes.labelsize': 14,
          'axes.titlesize': 14}
plt.rcParams.update({'font.size': 16})
plt.rcParams.update(parameters)
plt.rc('axes', labelsize=18) 
fig, ax = plt.subplots(figsize =(16, 9))
algos = list()
values = list()
Baverage1 = np.average(dqn[0:5])
values.append(Baverage1)
algos.append("DQN")
Baverage2 = np.average(ddqn[0:5])
values.append(Baverage2)
algos.append("DDQN")
Baverage3 = np.average(sta[0:5])
values.append(Baverage3)
algos.append("Sb-DQN")
Baverage4 = np.average(dyn[0:5])
values.append(Baverage4)
algos.append("Db-DQN")
data6 = pd.read_csv("result1/Ver1_Alg_result/FDQO_5phut_M900_1000_0.8_exlre0.0.csv").values[:100, 1]
Baverage6 = np.average(data6[0:5])
values.append(Baverage6)
algos.append("FDQO $\Theta = 0.8$")
data7 = pd.read_csv("result1/Ver1_Alg_result/FDQO_5phut_M900_1000_0.85.csv").values[:101, 1]
Baverage7 = np.average(data7[0:5])
values.append(Baverage7)
algos.append("FDQO $\Theta = 0.85$")
data8 = pd.read_csv("result1/Ver1_Alg_result/FDQO_5phut_M900_1000_0.9_exlre0.0.csv").values[:101, 1]
Baverage8 = np.average(data8[0:5])
values.append(Baverage8)
algos.append("FDQO $\Theta = 0.9$")
data9 = pd.read_csv("result1/Ver1_Alg_result/FDQO_5phut_M900_1000_0.95_exlre0.0.csv").values[:101, 1]
Baverage9 = np.average(data9[0:5])
values.append(Baverage9)
algos.append("FDQO $\Theta = 0.95$")
data10 = pd.read_csv("result1/Ver1_Alg_result/FDQO_5phut_all_fuzzy.csv").values[:101, 1]
Baverage10 = np.average(data10[0:5])
values.append(Baverage10)
algos.append("Fuzzy $\Theta = 1.0$")
#data11 = pd.read_csv("FDQO_5phut_M900_1000_baseline_200steps_g0.9_3.csv").values[:101, 1]
Baverage11 = np.average(bfdqo[0:5])
values.append(Baverage11)
algos.append("b-FDQO")
# data121 = pd.read_csv("FDQO_5phut_M900_1000_baseline_0.9_g0.5_4.csv").values[:101, 1]
# Baverage121 = np.average(data121[0:5])
# values.append(Baverage121)
# algos.append("b-FDQO 2")
# data12 = pd.read_csv("FDQO_5phut_M900_1000_0.9_baseline0.4_g0.5_queue2k.csv").values[:101, 1]
# Baverage12 = np.average(data12[0:5])
# values.append(Baverage12)
# algos.append("b-FDQO 3")
 
# creating the bar plot
ax.barh(algos, values, color ='maroon')
ax.set_yticks(algos)
ax.axvline(Baverage3, color = 'blue', linestyle = '-' )
plt.text(Baverage3, 1.5, str(round(Baverage3,4)), fontsize = 15, color = 'blue', rotation=-90)
ax.axvline(Baverage11, color = 'green', linestyle = '-' )
plt.text(Baverage11, 8.5, str(round(Baverage11,4)), fontsize = 15, color = 'green', rotation=-90)
plt.xlabel("Average QoE")
plt.savefig("../Pictures/First_5_time_slots.pdf")
plt.show()

# %%
Baverage11 / Baverage3
# Out:
# 1.5511706696880811

# %%
data1 = pd.read_csv("result1/RGreedy/1/n_quality_tasks.csv")

alg = "DQN"
datat = pd.read_csv("result1/" + alg + "/"+str(1)+"/n_quality_tasks.csv")
for i in range(2, 11):
    datat += pd.read_csv("result1/" + alg + "/"+str(i)+"/n_quality_tasks.csv")   
datat /= 10
data2 = datat

alg = "DDQN"
datat = pd.read_csv("result1/" + alg + "/"+str(1)+"/n_quality_tasks.csv")
for i in range(2, 11):
    datat += pd.read_csv("result1/" + alg + "/"+str(i)+"/n_quality_tasks.csv")  
datat /= 10
data3 = datat

alg = "Db-DQN_b_0.55_k_0.6_e_0.12"
datat = pd.read_csv("result1/" + alg + "/"+str(1)+"/n_quality_tasks.csv")
for i in range(2, 11):
    datat += pd.read_csv("result1/" + alg + "/"+str(i)+"/n_quality_tasks.csv")   
datat /= 10
data4 = datat

data5 = pd.read_csv("result1/Ver1_Alg_result/n_quality_tasks_fdqo_M900_1000_0.9_exlre0.0.csv", sep=',', 
                      names=["good", "medium", "bad"])

alg = "b-FDQO_b_0.5_k_0.6_e_0.12"
datat = pd.read_csv("result1/" + alg + "/"+str(1)+"/n_quality_tasks.csv")
for i in range(2, 11):
    datat += pd.read_csv("result1/" + alg + "/"+str(i)+"/n_quality_tasks.csv")   
datat /= 10
data6 = datat

#data1, data2, data3, data4, data5, data6

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('default')
import pandas as pd

plt.rcParams['figure.figsize'] = [12, 6]
plt.rcParams['figure.dpi'] = 100 # 200 e.g. is really fine, but slower
plt.rcParams.update({'font.size': 30})
plt.rc('axes', labelsize=30) 

def draw_good_average_bad_area_plot(data, file_name):
    Cov = data
    columns_titles = ["bad","medium", "good"]
    df = Cov.divide(Cov.sum(axis=1), axis=0)
    df = df.reindex(columns=columns_titles)
    #df.plot.area(legend = 'reverse', xlim = [0,100], ylim = [0,1])
    ax = df.plot.area(legend = False, xlim = [0,100], ylim = [0,1], fontsize=100)
#     plt.legend(ncol = 3)
#     legend = plt.legend(ncol = 3)
#     fig  = legend.figure
#     fig.canvas.draw()
#     bbox  = legend.get_window_extent().transformed(fig.dpi_scale_trans.inverted())
#     fig.savefig("../../Pictures/good_bad_legend.pdf", dpi="figure", bbox_inches=bbox)
    plt.xlabel("Time slots")
    plt.gca().xaxis.label.set_size(20)
    plt.gca().yaxis.label.set_size(20)
    plt.tick_params(which='major', labelsize=15)
   # plt.savefig("../Pictures/n_quality_task_"+file_name+".pdf")
    plt.show()
    
#draw_good_average_bad_area_plot("n_quality_tasks_RGreedy_M900_1000.csv")
#draw_good_average_bad_area_plot("../csvFilesNorm200steps/n_quality_tasks_fdqo_M900_1000_0.9_baseline0.4_g0.5_queue2k.csv")

# %%
draw_good_average_bad_area_plot(data1, "Greedy")
draw_good_average_bad_area_plot(data2, "DQN")
draw_good_average_bad_area_plot(data3, "DDQN")
draw_good_average_bad_area_plot(data4, "Db-DQN")
draw_good_average_bad_area_plot(data5, "FDQO")
draw_good_average_bad_area_plot(data6, "b-FDQO")

# %%
Cov = data1
columns_titles = ["bad","medium", "good"]
df = Cov.divide(Cov.sum(axis=1), axis=0)
df = df.reindex(columns=columns_titles)
#df.plot.area(legend = 'reverse', xlim = [0,100], ylim = [0,1])
df.plot.area(legend = False, xlim = [0,100], ylim = [0,1])
plt.legend(ncol = 3)
legend = plt.legend(ncol = 3)
fig  = legend.figure
fig.canvas.draw()
bbox  = legend.get_window_extent().transformed(fig.dpi_scale_trans.inverted())
fig.savefig("../Pictures/good_bad_legend.pdf", dpi="figure", bbox_inches=bbox)
plt.xlabel("Time slots")
plt.gca().xaxis.label.set_size(15)
plt.gca().yaxis.label.set_size(15)
plt.tick_params(which='major', labelsize=15)
#plt.savefig("../../Pictures/"+file_path[:-4]+".pdf")
plt.show()

# %%
alg = "DQN"
datat = pd.read_csv("result1/" + alg + "/"+str(1)+"/cb_5phut.csv").values[:201, 1]
for i in range(2, 11):
    datat += pd.read_csv("result1/" + alg + "/"+str(i)+"/cb_5phut.csv").values[:201, 1]    
datat /= 10
dataDQN = datat[:101]

# %%
dataDQN.shape, data4.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13716/3482007603.py in <module>
# ----> 1 dataDQN.shape, data4.shape
#
# NameError: name 'data4' is not defined

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('default')
import pandas as pd

plt.rcParams.update({'font.size': 14})
plt.rcParams['figure.figsize'] = [12, 6]
plt.rcParams['figure.dpi'] = 100 # 200 e.g. is really fine, but slower
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
a = 0
b = 100
data4 = pd.read_csv("result1/Ver1_Alg_result/FDQO_5phut_M900_1000_0.85.csv").values[:101, 1]
data5 = pd.read_csv("result1/Ver1_Alg_result/FDQO_5phut_M900_1000_0.8_exlre0.0.csv").values[:101, 1]
data55 = pd.read_csv("result1/Ver1_Alg_result/FDQO_5phut_M900_1000_0.9_exlre0.0.csv").values[:101, 1]
data6 = pd.read_csv("result1/Ver1_Alg_result/FDQO_5phut_all_fuzzy.csv").values[:101, 1]
#data7 = pd.read_csv("result1/Ver1_Alg_result/FDQO_5phut_M900_1000_0.2.csv").values[:101, 1]
data8 = pd.read_csv("result1/Ver1_Alg_result/FDQO_5phut_M900_1000_0.95_exlre0.0.csv").values[:101, 1]
#data9 = pd.read_csv("FDQO_5phut_M900_1000_1.0_exlre0.0.csv").values[:100, 1]
#data10 = pd.read_csv("FDQO_5phut_M900_1000_0.95_exlre0.0.csv").values[:100, 1]
#data11 = pd.read_csv("result1/Ver1_Alg_result/FDQO_5phut_M900_1000_0.9_exlre0.1.csv").values[:101, 1]
#data12 = pd.read_csv("result1/Ver1_Alg_result/FDQO_5phut_M900_1000_0.9_fuzzy0.95.csv").values[:101, 1]

dataFDQO_all_fuzzy = pd.read_csv("result1/Ver1_Alg_result/FDQO_5phut_all_fuzzy.csv").values[:, 1]
number = [i for i in range(data4.shape[0])]
line1, = ax.plot(number, data5, color="red", label = "FDQO $\Theta = 0.8$")
line2, = ax.plot(number, [np.average(data5[a:b])] * data4.shape[0], color="red", linestyle = '--',
        label = "mean FDQO $\Theta = 0.8$")
line3, = ax.plot(number, data4, color="blue", label = "FDQO $\Theta = 0.85$")
line4, = ax.plot(number, [np.average(data4[a:b])] * data4.shape[0], color="blue", linestyle = '--',
        label = "mean FDQO $\Theta = 0.85$")
line5, = ax.plot(number, data55, color="green", label = "FDQO $\Theta = 0.9$")
line6, = ax.plot(number, [np.average(data55[a:b])] * data4.shape[0], color="green", linestyle = '--',
        label = "mean FDQO $\Theta = 0.9$")
line7, = ax.plot(number, data8, color="purple", label = "FDQO $\Theta = 0.95$")
line8, = ax.plot(number, [np.average(data8[a:b])] * data4.shape[0], color="purple", linestyle = '--',
        label = "mean FDQO $\Theta = 0.95$")
line9, = ax.plot(number, data6, color="orange", label = "FDQO $\Theta = 1.0$")
line10, = ax.plot(number, [np.average(data6[a:b])] * data4.shape[0], color="orange", linestyle = '--',
        label = "mean FDQO $\Theta = 1.0$")
# line11, = ax.plot(number, dataDQN, color="gray", label = "DQN$")
# line12, = ax.plot(number, [np.average(dataDQN[a:b])] * data4.shape[0], color="gray", linestyle = '--',
#         label = "mean FDQO $\Theta = 1.0$")
# plt.plot(number, data7, color="purple", label = "FDQO")
# plt.plot(number, [np.average(data7[a:b])] * data6.shape[0], color="purple", linestyle = '--')
# plt.plot(number, data9, color="black", label = "FDQO 1.0 exlre 0.0")
# plt.plot(number, [np.average(data9[a:b])] * data6.shape[0], color="black", linestyle = '--')
# plt.plot(number, data10, color="gray", label = "FDQO 0.95 exlre 0.0")
# plt.plot(number, [np.average(data10[a:b])] * data6.shape[0], color="gray")
# plt.plot(number, data11, color="red", label = "FDQO 0.9 exlre 0.1")
# plt.plot(number, [np.average(data11[a:b])] * data11.shape[0], color="red", linestyle = '--')
# plt.plot(number, data12, color="orange", label = "FDQO 0.9 fuzzy 0.95")
# plt.plot(number, [np.average(data12[a:b])] * data12.shape[0], color="orange", linestyle = '--')
#plt.title("Different thresholds of FDQOs")
ax.set_xlabel("Time slots")
ax.set_ylabel("Average QoE")
first_legend = plt.legend(handles=[line2, line4, line6, line8, line10], loc='lower right')
plt.gca().add_artist(first_legend)
plt.legend(handles=[line1, line3, line5, line7, line9], loc='upper center',
           ncol=3, fancybox=True, shadow=True)

# plt.legend(loc='upper center',
#           ncol=5, fancybox=True, shadow=True)
#ax.set_xticks(np.arange(0, 101, 5.0))
ax.axis([0, 100, 0, 1])
major_ticks = np.arange(0, 101, 20)
minor_ticks = np.arange(0, 101, 5)

ax.set_xticks(major_ticks)
ax.set_xticks(minor_ticks, minor=True)
ax.set_yticks(np.arange(0,1.05,0.2))
ax.set_yticks(np.arange(0,1.05,0.05), minor=True)

ax.grid(which='both')

# Or if you want different settings for the grids:
ax.grid(which='minor', alpha=0.2)
ax.grid(which='major', alpha=0.5)
plt.savefig("../Pictures/Diffent_thresholds_FDQO.pdf")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd 

a = 50
b = 100
plt.rcParams.update({'font.size': 14})
fig, ax = plt.subplots(figsize =(16, 9))
algos = list()
values = list()
Baverage1 = np.average(data5[a:b])
values.append(Baverage1)
algos.append("FDQO $\Theta = 0.8$")
Baverage2 = np.average(data4[a:b])
values.append(Baverage2)
algos.append("FDQO $\Theta = 0.85$")
Baverage3 = np.average(data55[a:b])
values.append(Baverage3)
algos.append("FDQO $\Theta = 0.9$")
Baverage4 = np.average(data8[a:b])
values.append(Baverage4)
algos.append("FDQO $\Theta = 0.95$")
Baverage6 = np.average(data6[a:b])
values.append(Baverage6)
algos.append("FDQO $\Theta = 1.0$")
Baverage7 = np.average(dataDQN[a:b])
values.append(Baverage7)
algos.append("DQN")
 
# creating the bar plot
ax.barh(algos, values, color ='maroon')
ax.set_yticks(algos)
ax.axvline(Baverage3, color = 'blue', linestyle = '-' )
#plt.text(Baverage3, 1.5, str(round(Baverage3,4)), fontsize = 15, color = 'blue', rotation=-90)
ax.axvline(Baverage7, color = 'green', linestyle = '-' )
#plt.text(Baverage6, 8.5, str(round(Baverage7,4)), fontsize = 15, color = 'green', rotation=-90)
ax.set_xlabel("Average QoE of the time slots 50-100")
#plt.savefig("../Pictures/First_5_time_slots.pdf")
plt.show()

# %%
all_time_slots = list()
last_time_slots = list()
fig, ax = plt.subplots(figsize =(16, 9))

plt.rcParams.update({'font.size': 14})
a = 0
b = 100
c = 60
d = 100
all_time_slots.append(data5[a:b].mean())
all_time_slots.append(data4[a:b].mean())
all_time_slots.append(data55[a:b].mean())
all_time_slots.append(data8[a:b].mean())
all_time_slots.append(data6[a:b].mean())
all_time_slots.append(dataDQN[a:b].mean())
last_time_slots.append(data5[c:d].mean())
last_time_slots.append(data4[c:d].mean())
last_time_slots.append(data55[c:d].mean())
last_time_slots.append(data8[c:d].mean())
last_time_slots.append(data6[c:d].mean())
last_time_slots.append(dataDQN[c:d].mean())

objects = ("FDQO $\Theta = 0.8$", "FDQO $\Theta = 0.85$", "FDQO $\Theta = 0.9$", "FDQO $\Theta = 0.95$",
          "FDQO $\Theta = 1.0$", "DQN")
y_pos = np.arange(len(objects))

#plt.rcParams['font.size'] = '11'
for index, value in enumerate(all_time_slots):
    plt.text(value, index-0.3, str("{:.4f}".format(value)), fontsize=16)
for index, value in enumerate(last_time_slots):
    plt.text(value, index+0.1, str("{:.4f}".format(value)), fontsize=16)
#plt.bar(y_pos, performance, align='center', alpha=0.5)
plt.barh(y_pos - 0.2, all_time_slots, 0.4, label = 'DCEAO')
plt.barh(y_pos + 0.2, last_time_slots, 0.4, label = 'DCO')
#plt.xticks(objects, y_pos)
plt.yticks(y_pos, objects)
plt.xlabel('Average QoE')
#ax.axis(xmin=0,xmax=0.8)
plt.xlim([0, 0.8])
plt.savefig("../Pictures/FDQO_vs_DQN.pdf")
plt.show()

# %%
y_pos, len(all_time_slots)
# Out:
# (array([0, 1, 2, 3, 4, 5]), 6)

# %%
import matplotlib.pyplot as plt
plt.clf()
colors = ["tab:orange", "tab:blue"]
f = lambda m,c: plt.plot([],[],marker=m, color=c, ls="none")[0]
handles = [f("s", colors[i]) for i in range(2)]
labels = ["last 40 time slots", "all time slots"]
legend = plt.legend(handles, labels, loc=3, framealpha=1, frameon=False, ncol=2)

def export_legend(legend, filename="legend.pdf"):
    fig  = legend.figure
    fig.canvas.draw()
    bbox  = legend.get_window_extent().transformed(fig.dpi_scale_trans.inverted())
    fig.savefig(filename, dpi="figure", bbox_inches=bbox)

export_legend(legend)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('default')
import pandas as pd

plt.rcParams.update({'font.size': 14})
plt.rcParams['figure.figsize'] = [12, 6]
plt.rcParams['figure.dpi'] = 100 # 200 e.g. is really fine, but slower
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

a = 5
b = 70
data2 = pd.read_csv("result1/FDQO_time_reduce_experience_rate/a/2/cb_5phut.csv").values[:101, 1]
number = [i for i in range(data2.shape[0])]
ax.plot(number, data2, color="red", label = "Pure Fuzzy first 4 time slots")
data6 = pd.read_csv("result1/FDQO_time_reduce_experience_rate/a/3/cb_5phut.csv").values[:101, 1]
ax.plot(number, data6, color="blueviolet", label = "Pure Fuzzy first 24 time slots")
ax.plot(number, dataDQN, color="blue", label = "DQN")
data55 = pd.read_csv("result1/Ver1_Alg_result/FDQO_5phut_M900_1000_0.9_exlre0.0.csv").values[:101, 1]
ax.plot(number, data55, color="c", label = "FDQO")
plt.xlabel("Time slots")
plt.ylabel("Average QoE")
plt.legend(ncol=2, fancybox=True, shadow=True)
ax.axis([0, 100, 0, 1])
major_ticks = np.arange(0, 101, 20)
minor_ticks = np.arange(0, 101, 5)

ax.set_xticks(major_ticks)
ax.set_xticks(minor_ticks, minor=True)
ax.set_yticks(np.arange(0,1.05,0.2))
ax.set_yticks(np.arange(0,1.05,0.05), minor=True)

ax.grid(which='both')

# Or if you want different settings for the grids:
ax.grid(which='minor', alpha=0.2)
ax.grid(which='major', alpha=0.5)
plt.savefig("../Pictures/Review1_stop_pure_fuzzy.pdf")
plt.show()

# %%
alg = "b-FDQO_b_0.5_k_0.6_e_0.12"
datat = pd.read_csv("result1/" + alg + "/"+str(1)+"/cb_5phut.csv").values[:201, 1]
for i in range(2, 11):
    datat += pd.read_csv("result1/" + alg + "/"+str(i)+"/cb_5phut.csv").values[:201, 1]    
datat /= 10
data_b_FDQO = datat

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('default')
import pandas as pd
from scipy.interpolate import make_interp_spline

plt.rcParams.update({'font.size': 14})
plt.rcParams['figure.figsize'] = [12, 6]
plt.rcParams['figure.dpi'] = 100 # 200 e.g. is really fine, but slower
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

#data1 = pd.read_csv("FDQO_5phut_M900_1000_200steps_g0.9.csv").values[:201, 1]
#data1 = pd.read_csv("result1/Ver1_Alg_result/FDQO_5phut_M900_1000_0.9_200steps.csv").values[:201, 1]
# data2 = pd.read_csv("BDQL_5phut_M900_1000_200steps_gamma_0.9.csv").values[:201, 1]
# data3 = pd.read_csv("FDQO_5phut_M900_1000_0.9_baseline0.4_g0.5_queue2k.csv").values[:201, 1]
# data4 = pd.read_csv("FDQO_5phut_M900_1000_0.9_g0.7.csv.csv").values[:201, 1]
# data5 = pd.read_csv("FDQO_5phut_M900_1000_200steps_g0.9.csv").values[:201, 1]
# data6 = pd.read_csv("FDQO_5phut_M900_1000_0.9_g0.6.csv").values[:201, 1]
# data61 = pd.read_csv("../First5timeslots/FDQO_5phut_M900_1000_0.9_g0.5.csv").values[:201, 1]
# data7 = pd.read_csv("result1/RGreedy/1/RGreedy_5phut.csv").values[:201, 2]
number = [i for i in range(dataDQN.shape[0])]
moving_average_step = 40

df2 = pd.DataFrame(data=data2, columns=["value"])
df_ma2 = df2.value.rolling(moving_average_step, center=False, closed='left').mean()
df_ma2.plot(color="red", label = "FDQO stop Fuzzy after 30k time slots")

df3 = pd.DataFrame(data=data6, columns=["value"])
df_ma3 = df3.value.rolling(moving_average_step, center=False, closed='left').mean()
df_ma3.plot(color="blueviolet", label = "FDQO stop Fuzzy after 5k time slots")

df1 = pd.DataFrame(data=dataDQN, columns=["value"])
df_ma1 = df1.value.rolling(moving_average_step, center=False, closed='left').mean()
df_ma1.plot(color="blue", label = "DQN")

df7 = pd.DataFrame(data=data55, columns=["value"])
df_ma7 = df7.value.rolling(moving_average_step, center=False, closed='left').mean()
df_ma7.plot(color="c", label = "FDQO")

dfbFDQO = pd.DataFrame(data=data_b_FDQO, columns=["value"])
df_bFDQO = dfbFDQO.value.rolling(moving_average_step, center=False, closed='left').mean()
df_bFDQO.plot(color="green", label = "b-FDQO")

plt.xlabel("Time slots")
plt.ylabel("Average QoE")
plt.legend(fancybox=True, shadow=True)
# plt.xticks(np.arange(0, 101, 5.0))
# plt.axis([0, 100, 0, 1])
ax.axis([moving_average_step, 100, 0.5, 0.75])
major_ticks = np.arange(moving_average_step, 101, 10)
minor_ticks = np.arange(moving_average_step, 101, 5)

ax.set_xticks(major_ticks)
ax.set_xticks(minor_ticks, minor=True)
ax.set_yticks(np.arange(0.5,0.8,0.05))
ax.set_yticks(np.arange(0.5,0.8,0.05), minor=True)

ax.grid(which='both')

# Or if you want different settings for the grids:
ax.grid(which='minor', alpha=0.2)
ax.grid(which='major', alpha=0.5)
plt.savefig("../Pictures/Review1_stop_fuzzy_moving_average.pdf")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('default')
import pandas as pd

plt.rcParams.update({'font.size': 14})
plt.rcParams['figure.figsize'] = [12, 6]
plt.rcParams['figure.dpi'] = 100 # 200 e.g. is really fine, but slower
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

a = 5
b = 70
number = [i for i in range(dataDQN.shape[0])]
ax.plot(number, dataDQN, color="red", label = "Pure Fuzzy first 30k time steps")
data6 = pd.read_csv("result1/DQN_MaxBoltzmannQPolicy/eps_0.1_tau_1.0_clipmin_100/3/cb_5phut.csv").values[:101, 1]
ax.plot(number, data6, color="blueviolet", label = "Pure Fuzzy first 5k time steps")
ax.plot(number, data7[0:101], color="green", label = "Pure Fuzzy first 5k time steps")

plt.xlabel("Time slots")
plt.ylabel("Average QoE")
plt.legend(ncol=2, fancybox=True, shadow=True)
ax.axis([0, 100, 0, 1])
major_ticks = np.arange(0, 101, 20)
minor_ticks = np.arange(0, 101, 5)

ax.set_xticks(major_ticks)
ax.set_xticks(minor_ticks, minor=True)
ax.set_yticks(np.arange(0,1.05,0.2))
ax.set_yticks(np.arange(0,1.05,0.05), minor=True)

ax.grid(which='both')

# Or if you want different settings for the grids:
ax.grid(which='minor', alpha=0.2)
ax.grid(which='major', alpha=0.5)
plt.show()
